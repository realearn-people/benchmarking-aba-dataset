# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

output_file = 'output_formatted_ABA_dataset_2_gpt4o_5_shot_1_1.csv'
answer_key_file = '/Users/nonny/Downloads/Answer.xlsx'

df_output = pd.read_csv(output_file)
df_answer_key = pd.read_excel(answer_key_file)

# %%
df_answer_key.head(30)
# Out:
#     Column1                                              Title  \
# 0         1                           Wonderful place to stay.
# 1         1                           Wonderful place to stay.
# 2         1                           Wonderful place to stay.
# 3         1                           Wonderful place to stay.
# 4         1                           Wonderful place to stay.
# 5         3                                          Very Good
# 6         4                                          Wonderful
# 7         4                                          Wonderful
# 8         4                                          Wonderful
# 9         5  Fantastic value for a new, modern and spotless...
# 10        5  Fantastic value for a new, modern and spotless...
# 11        6                                          Wonderful
# 12        6                                          Wonderful
# 13        7                                   lovely stop over
# 14        8                   great place for few days to stay
# 15        8                   great place for few days to stay
# 16        8                   great place for few days to stay
# 17        9  such helpful hosts.helped us with map .helps w...
# 18        9  such helpful hosts.helped us with map .helps w...
# 19       10              Great overnight stay before a flight.
# 20       10              Great overnight stay before a flight.
# 21       11                                        Exceptional
# 22       11                                        Exceptional
# 23       11                                        Exceptional
# 24       11                                        Exceptional
# 25       11                                        Exceptional
# 26       12  Easy to get to and park. Lovely hotel, great h...
# 27       12  Easy to get to and park. Lovely hotel, great h...
# 28       12  Easy to get to and park. Lovely hotel, great h...
# 29       12  Easy to get to and park. Lovely hotel, great h...
#
#                                        PositiveReview  \
# 0   New, comfortable apartments, close to the airp...
# 1   New, comfortable apartments, close to the airp...
# 2   New, comfortable apartments, close to the airp...
# 3   New, comfortable apartments, close to the airp...
# 4   New, comfortable apartments, close to the airp...
# 5   the location is great and near the airport. bu...
# 6           Great stuff\n Great Quality/price\n Clean
# 7           Great stuff\n Great Quality/price\n Clean
# 8           Great stuff\n Great Quality/price\n Clean
# 9   Clean and modern with very comfortable beds, i...
# 10  Clean and modern with very comfortable beds, i...
# 11  We only stayed over night before heading to th...
# 12  We only stayed over night before heading to th...
# 13                                              great
# 14         nice location, lovely personal, renovated,
# 15         nice location, lovely personal, renovated,
# 16         nice location, lovely personal, renovated,
# 17  couldn't eat breakfast due to dietary restrict...
# 18  couldn't eat breakfast due to dietary restrict...
# 19  Great modern room comfortable bed and quiet lo...
# 20  Great modern room comfortable bed and quiet lo...
# 21  My second time here and true to say it was bet...
# 22  My second time here and true to say it was bet...
# 23  My second time here and true to say it was bet...
# 24  My second time here and true to say it was bet...
# 25  My second time here and true to say it was bet...
# 26  The staff were exceptional. So helpful and fri...
# 27  The staff were exceptional. So helpful and fri...
# 28  The staff were exceptional. So helpful and fri...
# 29  The staff were exceptional. So helpful and fri...
#
#                                        NegativeReview     Topic  \
# 0                                     Nothing at all.  Facility
# 1                                     Nothing at all.  Location
# 2                                     Nothing at all.     Staff
# 3                                     Nothing at all.      Food
# 4                                     Nothing at all.       Off
# 5                                                 NaN  Location
# 6                                                 NaN     Staff
# 7                                                 NaN     Price
# 8                                                 NaN      Room
# 9                                                 NaN      Room
# 10                                                NaN  Location
# 11                                                NaN      Room
# 12                                                NaN       Off
# 13                                                NaN       Off
# 14                                            nothing  Location
# 15                                            nothing     Staff
# 16                                            nothing       Off
# 17  maybe possibility of purchasing fresh fruit or...     Staff
# 18  maybe possibility of purchasing fresh fruit or...       Off
# 19                                                NaN      Room
# 20                                                NaN  Location
# 21                                                NaN     Staff
# 22                                                NaN      Food
# 23                                                NaN      Room
# 24                                                NaN  Location
# 25                                                NaN       Off
# 26                               Couldn’t stay longer     Staff
# 27                               Couldn’t stay longer      Food
# 28                               Couldn’t stay longer      Room
# 29                               Couldn’t stay longer       Off
#
#                                      Selected Content   Pos/Neg  \
# 0                         New, comfortable apartments  Positive
# 1          close to the airport, to very clean beach.  Positive
# 2   Staff is extremely helpful and easy to communi...  Positive
# 3   Tasty food on the first floor, comfortable res...  Positive
# 4   on the first floor, to escape the heat in the ...       NaN
# 5   the location is great and near the airport. bu...  Positive
# 6                                         Great stuff  Positive
# 7                                 Great Quality/price  Positive
# 8                                               Clean  Positive
# 9         Clean and modern with very comfortable beds  Positive
# 10  in a very convenient location.  An easy stroll...  Positive
# 11  The room was exceptionally clean with a really...  Positive
# 12  We only stayed over night before heading to th...  Positive
# 13                                              great  Positive
# 14                                      nice location  Positive
# 15                                    lovely personal  Positive
# 16                                 renovated, nothing  Positive
# 17  very helpful host showed us how nearby bus tak...  Positive
# 18  couldn't eat breakfast due to dietary restrict...       NaN
# 19                  Great modern room comfortable bed  Positive
# 20                                     quiet location  Positive
# 21  The staff here are amazing beyond expectations...  Positive
# 22  Oh yeah the food is great to and very reasonab...  Positive
# 23  The rooms are spacious and clean great to stay...  Positive
# 24  The bus stop which goes to and from the airpor...  Positive
# 25   My second time here and true to say it was be...  Positive
# 26  The staff were exceptional. So helpful and fri...  Positive
# 27    The breakfast was lovely with room service too.  Positive
# 28                        Very clean and comfortable.  Positive
# 29                               Couldn’t stay longer       NaN
#
#              Head                               Body 1  \
# 0   good_facility                            new_hotel
# 1   good_location                     close_to_airport
# 2      good_staff                        helpful_staff
# 3       good_food                           tasty_food
# 4             NaN                                  NaN
# 5   good_location                       great_location
# 6      good_staff                          great_staff
# 7      good_price                        great_quality
# 8       good_room                           clean_room
# 9       good_room                           clean_room
# 10  good_location                  convenient_location
# 11      good_room                           clean_room
# 12            NaN                                  NaN
# 13            NaN                                  NaN
# 14  good_location                        nice_location
# 15     good_staff                         lovely_staff
# 16            NaN                                  NaN
# 17     good_staff                        helpful_staff
# 18            NaN                                  NaN
# 19      good_room                           great_room
# 20  good_location                       quiet_location
# 21     good_staff                        amazing_staff
# 22      good_food                           great_food
# 23      good_room                        spacious_room
# 24  good_location  minutes_walk_to_bus_stop_to_airport
# 25            NaN                                  NaN
# 26     good_staff                    exceptional_staff
# 27      good_food   lovely_breakfast_with_room_service
# 28      good_room                           clean_room
# 29            NaN                                  NaN
#
#                                            Body 2  ... Cont. Body 12  \
# 0                               comfortable_hotel  ...           NaN
# 1                            close_to_clean_beach  ...           NaN
# 2                        easy_to_communicate_with  ...           NaN
# 3         comfortable_restaurant_for_cozy_evening  ...           NaN
# 4                                             NaN  ...           NaN
# 5                                    near_airport  ...           NaN
# 6                                             NaN  ...           NaN
# 7                                     great_price  ...           NaN
# 8                                             NaN  ...           NaN
# 9                                     modern_room  ...           NaN
# 10                 easy_stroll_to_nice_restaurant  ...           NaN
# 11                                comfortable_bed  ...           NaN
# 12                                            NaN  ...           NaN
# 13                                            NaN  ...           NaN
# 14                                            NaN  ...           NaN
# 15                                            NaN  ...           NaN
# 16                                            NaN  ...           NaN
# 17  staff_show_how_nearby_bus_take_to_town_center  ...           NaN
# 18                                            NaN  ...           NaN
# 19                                    modern_room  ...           NaN
# 20                                            NaN  ...           NaN
# 21                             beyond_expectation  ...           NaN
# 22                               reasonable_price  ...           NaN
# 23                                     clean_room  ...           NaN
# 24          minutes_walk_to_bus_stop_from airport  ...           NaN
# 25                                            NaN  ...           NaN
# 26                                  helpful_staff  ...           NaN
# 27                                            NaN  ...           NaN
# 28                               comfortable_room  ...           NaN
# 29                                            NaN  ...           NaN
#
#    Cont. Body 13 Cont. Body 14 Cont. Body 15  \
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2            NaN           NaN           NaN
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7            NaN           NaN           NaN
# 8            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 10           NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 13           NaN           NaN           NaN
# 14           NaN           NaN           NaN
# 15           NaN           NaN           NaN
# 16           NaN           NaN           NaN
# 17           NaN           NaN           NaN
# 18           NaN           NaN           NaN
# 19           NaN           NaN           NaN
# 20           NaN           NaN           NaN
# 21           NaN           NaN           NaN
# 22           NaN           NaN           NaN
# 23           NaN           NaN           NaN
# 24           NaN           NaN           NaN
# 25           NaN           NaN           NaN
# 26           NaN           NaN           NaN
# 27           NaN           NaN           NaN
# 28           NaN           NaN           NaN
# 29           NaN           NaN           NaN
#
#                                                Concat  Claim  \
# 0   new_hotel , comfortable_hotel , no_evident_not...    NaN
# 1   close_to_airport , close_to_clean_beach , no_e...  Claim
# 2   helpful_staff , easy_to_communicate_with , no_...    NaN
# 3   tasty_food , comfortable_restaurant_for_cozy_e...    NaN
# 4                                                 NaN    NaN
# 5   great_location , near_airport , close_to_bus_s...  Claim
# 6            great_staff , no_evident_not_great_staff  Claim
# 7   great_quality , great_price , no_evident_not_g...    NaN
# 8              clean_room , no_evident_not_clean_room    NaN
# 9   clean_room , modern_room , comfortable_bed , n...  Claim
# 10  convenient_location , easy_stroll_to_nice_rest...    NaN
# 11  clean_room , comfortable_bed , no_evident_not_...  Claim
# 12                                                NaN    NaN
# 13                                                NaN  Claim
# 14       nice_location , no_evident_not_nice_location  Claim
# 15         lovely_staff , no_evident_not_lovely_staff    NaN
# 16                                                NaN    NaN
# 17  helpful_staff , staff_show_how_nearby_bus_take...  Claim
# 18                                                NaN    NaN
# 19  great_room , modern_room , comfortable_bed , n...  Claim
# 20     quiet_location , no_evident_not_quiet_location    NaN
# 21  amazing_staff , beyond_expectation , great_sta...  Claim
# 22  great_food , reasonable_price , no_evident_not...    NaN
# 23  spacious_room , clean_room , great_to_stay , g...    NaN
# 24  minutes_walk_to_bus_stop_to_airport , minutes_...    NaN
# 25                                                NaN    NaN
# 26  exceptional_staff , helpful_staff , friendly_s...  Claim
# 27  lovely_breakfast_with_room_service , no_eviden...    NaN
# 28  clean_room , comfortable_room , no_evident_not...    NaN
# 29                                                NaN    NaN
#
#    PositiveReview Relevancy NegativeReview Relevancy Column2 Column3
# 0                       NaN                      NaN     NaN     NaN
# 1                       Yes      Noise Negative Null     0.0   785.0
# 2                       NaN                      NaN     NaN     NaN
# 3                       NaN                      NaN     NaN     NaN
# 4                       NaN                      NaN     NaN     NaN
# 5                       Yes      Noise Negative Null     NaN     NaN
# 6                       Yes      Noise Negative Null     NaN     NaN
# 7                       NaN                      NaN     NaN     NaN
# 8                       NaN                      NaN     NaN     NaN
# 9                       Yes      Noise Negative Null     NaN     NaN
# 10                      NaN                      NaN     NaN     NaN
# 11                      Yes      Noise Negative Null     NaN     NaN
# 12                      NaN                      NaN     NaN     NaN
# 13                      Yes      Noise Negative Null     NaN     NaN
# 14                      Yes      Noise Negative Null     NaN     NaN
# 15                      NaN                      NaN     NaN     NaN
# 16                      NaN                      NaN     NaN     NaN
# 17                      Yes                       No     NaN     NaN
# 18                      NaN                      NaN     NaN     NaN
# 19                      Yes      Noise Negative Null     NaN     NaN
# 20                      NaN                      NaN     NaN     NaN
# 21                      Yes      Noise Negative Null     NaN     NaN
# 22                      NaN                      NaN     NaN     NaN
# 23                      NaN                      NaN     NaN     NaN
# 24                      NaN                      NaN     NaN     NaN
# 25                      NaN                      NaN     NaN     NaN
# 26                      Yes      Noise Negative Null     NaN     NaN
# 27                      NaN                      NaN     NaN     NaN
# 28                      NaN                      NaN     NaN     NaN
# 29                      NaN                      NaN     NaN     NaN
#
# [30 rows x 44 columns]

# %%
# Clean answer key
df_answer_cleaned = df_answer_key[['Column1', 'Topic', 'Selected Content', 'Pos/Neg']].rename(columns={
    'Column1': 'ID',
    'Topic': 'Topics',
    'Selected Content': 'Text',
    'Pos/Neg': 'NegPos'
})

# df_answer_cleaned.head(30)

# %%
# Clean Output
def clean_topic(topic):
    return re.sub(r'\d+$', '', str(topic))

df_output['Cleaned_Topics'] = df_output['Topics'].apply(clean_topic)

df_output_cleaned = df_output[['ID', 'Cleaned_Topics', 'Text', 'NegPos']].copy()
df_output_cleaned.rename(columns={'Cleaned_Topics': 'Topics'}, inplace=True)
df_output_cleaned = df_output_cleaned[~(df_output_cleaned['Text'].isna() & df_output_cleaned['NegPos'].isna())]

# df_output_cleaned.head(30)

df_output_merged = df_output_cleaned.groupby(['ID', 'Topics', 'NegPos']).agg({
    'Text': lambda x: ', '.join(x.dropna().astype(str).str.strip())
}).reset_index()


# df_output_merged.head(30)
df_output_merged[df_output_merged['ID'] == 22]
# Out:
#     ID Topics    NegPos                                               Text
# 54  22   Food  Negative  Ordered pizza one night and was not great, too...
# 55  22   Food  Positive                       the restaurant area is nice.
# 56  22    Off      Null                     I'm sure other food is better.
# 57  22   Room  Negative  might have needed another set of drawers if th...
# 58  22   Room  Positive  Room was perfect, looked new, clean shiny tile...
# 59  22  Staff  Positive                      the staff very accommodating.

# %%
df_compare = pd.merge(
    df_answer_cleaned.rename(columns={'NegPos': 'NegPos_answer', 'Text': 'Text_answer'}),
    df_output_merged.rename(columns={'NegPos': 'NegPos_output', 'Text': 'Text_output'}),
    left_on=['ID', 'Topics', 'NegPos_answer'],
    right_on=['ID', 'Topics', 'NegPos_output'],
    how='outer'
)

df_compare = df_compare[df_compare['Topics'] != 'Off']

df_compare.head(30)
# df_compare[df_compare['ID'] == 22]
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1  Facility                        New, comfortable apartments
# 1    1      Food  Tasty food on the first floor, comfortable res...
# 2    1  Location         close to the airport, to very clean beach.
# 5    1      Room                                                NaN
# 6    1     Staff  Staff is extremely helpful and easy to communi...
# 7    3  Location  the location is great and near the airport. bu...
# 8    4     Price                                Great Quality/price
# 9    4      Room                                              Clean
# 10   4     Staff                                        Great stuff
# 11   5  Location  in a very convenient location.  An easy stroll...
# 12   5      Room        Clean and modern with very comfortable beds
# 15   6      Room  The room was exceptionally clean with a really...
# 18   8  Facility                                                NaN
# 19   8  Location                                      nice location
# 21   8     Staff                                    lovely personal
# 22   9      Food                                                NaN
# 23   9      Food                                                NaN
# 26   9     Price                                                NaN
# 27   9     Staff  very helpful host showed us how nearby bus tak...
# 28  10  Location                                     quiet location
# 29  10      Room                  Great modern room comfortable bed
# 30  11      Food  Oh yeah the food is great to and very reasonab...
# 31  11  Location  The bus stop which goes to and from the airpor...
# 33  11      Room  The rooms are spacious and clean great to stay...
# 34  11     Staff  The staff here are amazing beyond expectations...
# 35  12      Food    The breakfast was lovely with room service too.
# 38  12      Room                        Very clean and comfortable.
# 39  12     Staff  The staff were exceptional. So helpful and fri...
# 40  13  Location  Short drive to the airport and very well locat...
# 42  13      Room  The rooms are lovely and new, very clean and c...
#
#    NegPos_answer NegPos_output  \
# 0       Positive           NaN
# 1       Positive      Positive
# 2       Positive      Positive
# 5            NaN      Positive
# 6       Positive      Positive
# 7       Positive      Positive
# 8       Positive      Positive
# 9       Positive      Positive
# 10      Positive      Positive
# 11      Positive      Positive
# 12      Positive      Positive
# 15      Positive      Positive
# 18           NaN      Positive
# 19      Positive      Positive
# 21      Positive      Positive
# 22           NaN      Negative
# 23           NaN      Positive
# 26           NaN      Positive
# 27      Positive      Positive
# 28      Positive      Positive
# 29      Positive      Positive
# 30      Positive      Positive
# 31      Positive      Positive
# 33      Positive      Positive
# 34      Positive      Positive
# 35      Positive      Positive
# 38      Positive      Positive
# 39      Positive      Positive
# 40      Positive      Positive
# 42      Positive      Positive
#
#                                           Text_output
# 0                                                 NaN
# 1   Tasty food on the first floor, comfortable res...
# 2          close to the airport, to very clean beach.
# 5                        New, comfortable apartments.
# 6   Staff is extremely helpful and easy to communi...
# 7   the location is great and near the airport. bu...
# 8                                 Great Quality/price
# 9                                               Clean
# 10                                        Great stuff
# 11  in a very convenient location. An easy stroll ...
# 12       Clean and modern with very comfortable beds.
# 15  The room was exceptionally clean with a really...
# 18                                          renovated
# 19                                      nice location
# 21                                    lovely personal
# 22  couldn't eat breakfast due to dietary restrict...
# 23       possibility of purchasing fresh fruit or veg
# 26                           no need for 21 euro taxi
# 27  very helpful host showed us how nearby bus tak...
# 28                                     quiet location
# 29                  Great modern room comfortable bed
# 30   the food is great to and very reasonable prices.
# 31  The bus stop which goes to and from the airpor...
# 33  The rooms are spacious and clean great to stay...
# 34  The staff here are amazing beyond expectations...
# 35    The breakfast was lovely with room service too.
# 38                        Very clean and comfortable.
# 39  The staff were exceptional. So helpful and fri...
# 40  Short drive to the airport and very well locat...
# 42  The rooms are lovely and new, very clean and c...

# %%
def sentiment_match(row):
    if pd.isna(row['NegPos_answer']) or pd.isna(row['NegPos_output']):
        return False  # Missing either → False
    return str(row['NegPos_answer']).strip().lower() == str(row['NegPos_output']).strip().lower()

df_compare['Sentiment_Match'] = df_compare.apply(sentiment_match, axis=1)

df_compare.head(30)
# df_compare[df_compare['ID'] == 22]
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1  Facility                        New, comfortable apartments
# 1    1      Food  Tasty food on the first floor, comfortable res...
# 2    1  Location         close to the airport, to very clean beach.
# 5    1      Room                                                NaN
# 6    1     Staff  Staff is extremely helpful and easy to communi...
# 7    3  Location  the location is great and near the airport. bu...
# 8    4     Price                                Great Quality/price
# 9    4      Room                                              Clean
# 10   4     Staff                                        Great stuff
# 11   5  Location  in a very convenient location.  An easy stroll...
# 12   5      Room        Clean and modern with very comfortable beds
# 15   6      Room  The room was exceptionally clean with a really...
# 18   8  Facility                                                NaN
# 19   8  Location                                      nice location
# 21   8     Staff                                    lovely personal
# 22   9      Food                                                NaN
# 23   9      Food                                                NaN
# 26   9     Price                                                NaN
# 27   9     Staff  very helpful host showed us how nearby bus tak...
# 28  10  Location                                     quiet location
# 29  10      Room                  Great modern room comfortable bed
# 30  11      Food  Oh yeah the food is great to and very reasonab...
# 31  11  Location  The bus stop which goes to and from the airpor...
# 33  11      Room  The rooms are spacious and clean great to stay...
# 34  11     Staff  The staff here are amazing beyond expectations...
# 35  12      Food    The breakfast was lovely with room service too.
# 38  12      Room                        Very clean and comfortable.
# 39  12     Staff  The staff were exceptional. So helpful and fri...
# 40  13  Location  Short drive to the airport and very well locat...
# 42  13      Room  The rooms are lovely and new, very clean and c...
#
#    NegPos_answer NegPos_output  \
# 0       Positive           NaN
# 1       Positive      Positive
# 2       Positive      Positive
# 5            NaN      Positive
# 6       Positive      Positive
# 7       Positive      Positive
# 8       Positive      Positive
# 9       Positive      Positive
# 10      Positive      Positive
# 11      Positive      Positive
# 12      Positive      Positive
# 15      Positive      Positive
# 18           NaN      Positive
# 19      Positive      Positive
# 21      Positive      Positive
# 22           NaN      Negative
# 23           NaN      Positive
# 26           NaN      Positive
# 27      Positive      Positive
# 28      Positive      Positive
# 29      Positive      Positive
# 30      Positive      Positive
# 31      Positive      Positive
# 33      Positive      Positive
# 34      Positive      Positive
# 35      Positive      Positive
# 38      Positive      Positive
# 39      Positive      Positive
# 40      Positive      Positive
# 42      Positive      Positive
#
#                                           Text_output  Sentiment_Match
# 0                                                 NaN            False
# 1   Tasty food on the first floor, comfortable res...             True
# 2          close to the airport, to very clean beach.             True
# 5                        New, comfortable apartments.            False
# 6   Staff is extremely helpful and easy to communi...             True
# 7   the location is great and near the airport. bu...             True
# 8                                 Great Quality/price             True
# 9                                               Clean             True
# 10                                        Great stuff             True
# 11  in a very convenient location. An easy stroll ...             True
# 12       Clean and modern with very comfortable beds.             True
# 15  The room was exceptionally clean with a really...             True
# 18                                          renovated            False
# 19                                      nice location             True
# 21                                    lovely personal             True
# 22  couldn't eat breakfast due to dietary restrict...            False
# 23       possibility of purchasing fresh fruit or veg            False
# 26                           no need for 21 euro taxi            False
# 27  very helpful host showed us how nearby bus tak...             True
# 28                                     quiet location             True
# 29                  Great modern room comfortable bed             True
# 30   the food is great to and very reasonable prices.             True
# 31  The bus stop which goes to and from the airpor...             True
# 33  The rooms are spacious and clean great to stay...             True
# 34  The staff here are amazing beyond expectations...             True
# 35    The breakfast was lovely with room service too.             True
# 38                        Very clean and comfortable.             True
# 39  The staff were exceptional. So helpful and fri...             True
# 40  Short drive to the airport and very well locat...             True
# 42  The rooms are lovely and new, very clean and c...             True

# %%
df_compare.to_csv('sentiment_result_5_shot_1.csv', index=False)

# %%
# Calculate accuracy
num_true = df_compare['Sentiment_Match'].sum()
num_total = len(df_compare)

accuracy = num_true / num_total

print(f"Accuracy: {accuracy * 100:.2f}%")
print(f"Correct (True): {num_true}")
print(f"Total Cases: {num_total}")
# Out:
# Accuracy: 80.32%
# Correct (True): 1465
# Total Cases: 1824
