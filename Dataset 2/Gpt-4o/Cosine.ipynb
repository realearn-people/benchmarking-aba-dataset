# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

output_file = 'output_formatted_ABA_dataset_2_gpt4o_5_shot_3_3.csv'
answer_key_file = '/Users/nonny/Downloads/Answer.xlsx'

df_output = pd.read_csv(output_file)
df_answer_key = pd.read_excel(answer_key_file)

# %%
# Clean answer key
df_answer_cleaned = df_answer_key[['Column1', 'Topic', 'Selected Content', 'Pos/Neg']].rename(columns={
    'Column1': 'ID',
    'Topic': 'Topics',
    'Selected Content': 'Text_answer',
    'Pos/Neg': 'NegPos_answer'
})

df_answer_cleaned.head(30)
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1  Facility                        New, comfortable apartments
# 1    1  Location         close to the airport, to very clean beach.
# 2    1     Staff  Staff is extremely helpful and easy to communi...
# 3    1      Food  Tasty food on the first floor, comfortable res...
# 4    1       Off  on the first floor, to escape the heat in the ...
# 5    3  Location  the location is great and near the airport. bu...
# 6    4     Staff                                        Great stuff
# 7    4     Price                                Great Quality/price
# 8    4      Room                                              Clean
# 9    5      Room        Clean and modern with very comfortable beds
# 10   5  Location  in a very convenient location.  An easy stroll...
# 11   6      Room  The room was exceptionally clean with a really...
# 12   6       Off  We only stayed over night before heading to th...
# 13   7       Off                                              great
# 14   8  Location                                      nice location
# 15   8     Staff                                    lovely personal
# 16   8       Off                                 renovated, nothing
# 17   9     Staff  very helpful host showed us how nearby bus tak...
# 18   9       Off  couldn't eat breakfast due to dietary restrict...
# 19  10      Room                  Great modern room comfortable bed
# 20  10  Location                                     quiet location
# 21  11     Staff  The staff here are amazing beyond expectations...
# 22  11      Food  Oh yeah the food is great to and very reasonab...
# 23  11      Room  The rooms are spacious and clean great to stay...
# 24  11  Location  The bus stop which goes to and from the airpor...
# 25  11       Off   My second time here and true to say it was be...
# 26  12     Staff  The staff were exceptional. So helpful and fri...
# 27  12      Food    The breakfast was lovely with room service too.
# 28  12      Room                        Very clean and comfortable.
# 29  12       Off                               Couldn’t stay longer
#
#    NegPos_answer
# 0       Positive
# 1       Positive
# 2       Positive
# 3       Positive
# 4            NaN
# 5       Positive
# 6       Positive
# 7       Positive
# 8       Positive
# 9       Positive
# 10      Positive
# 11      Positive
# 12      Positive
# 13      Positive
# 14      Positive
# 15      Positive
# 16      Positive
# 17      Positive
# 18           NaN
# 19      Positive
# 20      Positive
# 21      Positive
# 22      Positive
# 23      Positive
# 24      Positive
# 25      Positive
# 26      Positive
# 27      Positive
# 28      Positive
# 29           NaN

# %%
# Clean Output
def clean_topic(topic):
    return re.sub(r'\d+$', '', str(topic))

df_output['Cleaned_Topics'] = df_output['Topics'].apply(clean_topic)

df_output_cleaned = df_output[['ID', 'Cleaned_Topics', 'Text', 'NegPos']].copy()
df_output_cleaned.rename(columns={'Cleaned_Topics': 'Topics'}, inplace=True)
df_output_cleaned = df_output_cleaned[~(df_output_cleaned['Text'].isna() & df_output_cleaned['NegPos'].isna())]

# df_output_cleaned.head(30)

df_output_merged = df_output_cleaned.groupby(['ID', 'Topics', 'NegPos']).agg({
    'Text': lambda x: ', '.join(x.dropna().astype(str).str.strip())
}).reset_index()


# df_output_merged.head(30)
df_output_merged[df_output_merged['ID'] == 22]
# Out:
#     ID    Topics    NegPos                                               Text
# 54  22  Facility  Positive                       The restaurant area is nice.
# 55  22      Food  Negative  Ordered pizza one night and was not great, too...
# 56  22      Food  Positive                     I'm sure other food is better.
# 57  22      Room  Negative  might have needed another set of drawers if th...
# 58  22      Room  Positive  Room was perfect, looked new, clean shiny tile...
# 59  22     Staff  Positive                      the staff very accommodating.

# %%
# Merge on ID and Topics
# Use 'ID', 'Topics', and 'NegPos' as the keys to align the data
# 'NegPos' is renamed to 'NegPos_answer' in df_answer_cleaned before the merge, so we match on that
# Use an OUTER JOIN to capture all possible cases:
# - Matching (ID, Topics, Sentiment) pairs
# - Missing predictions (False Negatives)
# - Extra predictions (False Positives)
df_compare = pd.merge(
    df_answer_cleaned,
    df_output_merged,
    left_on=['ID', 'Topics', 'NegPos_answer'],
    right_on=['ID', 'Topics', 'NegPos'],
    how='outer',
    suffixes=('_answer', '_output')
)

df_compare.rename(columns={
    'Text': 'Text_output',
    'NegPos': 'NegPos_output'
}, inplace=True)

# Filter out rows where BOTH 'Text_answer' and 'Text_output' are missing or empty
df_compare = df_compare[~(
    (df_compare['Text_answer'].isna() | df_compare['Text_answer'].str.strip().eq('')) &
    (df_compare['Text_output'].isna() | df_compare['Text_output'].str.strip().eq(''))
)]

# Remove topics labeled as 'Off'
df_compare = df_compare[df_compare['Topics'] != 'Off']
df_compare.head(30)
# df_compare[df_compare['ID'] == 22]
# Out:
#     ID      Topics                                        Text_answer  \
# 0    1    Facility                        New, comfortable apartments
# 1    1        Food  Tasty food on the first floor, comfortable res...
# 2    1    Location         close to the airport, to very clean beach.
# 5    1        Room                                                NaN
# 6    1       Staff  Staff is extremely helpful and easy to communi...
# 7    3    Location  the location is great and near the airport. bu...
# 8    4       Price                                Great Quality/price
# 9    4        Room                                              Clean
# 10   4       Staff                                        Great stuff
# 11   5    Location  in a very convenient location.  An easy stroll...
# 12   5        Room        Clean and modern with very comfortable beds
# 15   6        Room  The room was exceptionally clean with a really...
# 17   8    Facility                                                NaN
# 18   8    Location                                      nice location
# 20   8       Staff                                    lovely personal
# 21   9        Food                                                NaN
# 22   9        Food                                                NaN
# 25   9       Staff  very helpful host showed us how nearby bus tak...
# 26   9  Taxi-issue                                                NaN
# 27  10    Location                                     quiet location
# 28  10        Room                  Great modern room comfortable bed
# 29  11        Food  Oh yeah the food is great to and very reasonab...
# 30  11    Location  The bus stop which goes to and from the airpor...
# 32  11        Room  The rooms are spacious and clean great to stay...
# 33  11       Staff  The staff here are amazing beyond expectations...
# 34  12        Food    The breakfast was lovely with room service too.
# 37  12        Room                        Very clean and comfortable.
# 38  12       Staff  The staff were exceptional. So helpful and fri...
# 39  13    Location  Short drive to the airport and very well locat...
# 41  13        Room  The rooms are lovely and new, very clean and c...
#
#    NegPos_answer NegPos_output  \
# 0       Positive           NaN
# 1       Positive      Positive
# 2       Positive      Positive
# 5            NaN      Positive
# 6       Positive      Positive
# 7       Positive      Positive
# 8       Positive      Positive
# 9       Positive      Positive
# 10      Positive      Positive
# 11      Positive      Positive
# 12      Positive      Positive
# 15      Positive      Positive
# 17           NaN      Positive
# 18      Positive      Positive
# 20      Positive      Positive
# 21           NaN      Negative
# 22           NaN      Positive
# 25      Positive      Positive
# 26           NaN      Positive
# 27      Positive      Positive
# 28      Positive      Positive
# 29      Positive      Positive
# 30      Positive      Positive
# 32      Positive      Positive
# 33      Positive      Positive
# 34      Positive      Positive
# 37      Positive      Positive
# 38      Positive      Positive
# 39      Positive      Positive
# 41      Positive      Positive
#
#                                           Text_output
# 0                                                 NaN
# 1   Tasty food on the first floor, comfortable res...
# 2          close to the airport, to very clean beach.
# 5                        New, comfortable apartments.
# 6   Staff is extremely helpful and easy to communi...
# 7   the location is great and near the airport. bu...
# 8                                 Great Quality/price
# 9                                               Clean
# 10                                        Great stuff
# 11  in a very convenient location. An easy stroll ...
# 12       Clean and modern with very comfortable beds.
# 15  The room was exceptionally clean with a really...
# 17                                          renovated
# 18                                      nice location
# 20                                    lovely personal
# 21  couldn't eat breakfast due to dietary restrict...
# 22       possibility of purchasing fresh fruit or veg
# 25  very helpful host showed us how nearby bus tak...
# 26                           no need for 21 euro taxi
# 27                                    quiet location.
# 28                 Great modern room comfortable bed.
# 29   the food is great to and very reasonable prices.
# 30  The bus stop which goes to and from the airpor...
# 32  The rooms are spacious and clean great to stay...
# 33  The staff here are amazing beyond expectations...
# 34    The breakfast was lovely with room service too.
# 37                        Very clean and comfortable.
# 38  The staff were exceptional. So helpful and fri...
# 39  Short drive to the airport and very well locat...
# 41  The rooms are lovely and new, very clean and c...

# %%
# Combine all text data from both the answer key and model output into a single list 
# - Use .fillna('') to replace NaN with empty strings to avoid errors
all_texts = df_compare['Text_answer'].fillna('').tolist() + df_compare['Text_output'].fillna('').tolist()

# Initialize the TF-IDF Vectorizer
# - lowercase=True: converts all text to lowercase for normalization
# - token_pattern=r"(?u)\b\w+\b": matches any single word (includes single letters and numbers), so it's more general than the default
vectorizer = TfidfVectorizer(lowercase=True, token_pattern=r"(?u)\b\w+\b")

vectorizer.fit(all_texts)
# Out:
# TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b')

# %%
# Define a function to compute cosine similarity between two text strings using TF-IDF
def compute_cosine(text1, text2, vectorizer):
    # Case 1: If either text is NaN, return 0 similarity
    if pd.isna(text1) or pd.isna(text2):
        return 0.0

    # Strip leading/trailing spaces to avoid issues with empty strings
    text1 = str(text1).strip()
    text2 = str(text2).strip()
    # Case 2: If either text is empty after stripping, return 0 similarity
    if text1 == '' or text2 == '':
        return 0.0

    # Transform both texts into TF-IDF vectors using the pre-fitted vectorizer
    tfidf = vectorizer.transform([text1, text2])
    return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]

df_compare['Cosine_Similarity'] = df_compare.apply(
    lambda row: compute_cosine(row['Text_answer'], row['Text_output'], vectorizer),
    axis=1
)

df_compare[['ID', 'Topics', 'Text_answer', 'Text_output', 'Cosine_Similarity']].head(30)
# Out:
#     ID      Topics                                        Text_answer  \
# 0    1    Facility                        New, comfortable apartments
# 1    1        Food  Tasty food on the first floor, comfortable res...
# 2    1    Location         close to the airport, to very clean beach.
# 5    1        Room                                                NaN
# 6    1       Staff  Staff is extremely helpful and easy to communi...
# 7    3    Location  the location is great and near the airport. bu...
# 8    4       Price                                Great Quality/price
# 9    4        Room                                              Clean
# 10   4       Staff                                        Great stuff
# 11   5    Location  in a very convenient location.  An easy stroll...
# 12   5        Room        Clean and modern with very comfortable beds
# 15   6        Room  The room was exceptionally clean with a really...
# 17   8    Facility                                                NaN
# 18   8    Location                                      nice location
# 20   8       Staff                                    lovely personal
# 21   9        Food                                                NaN
# 22   9        Food                                                NaN
# 25   9       Staff  very helpful host showed us how nearby bus tak...
# 26   9  Taxi-issue                                                NaN
# 27  10    Location                                     quiet location
# 28  10        Room                  Great modern room comfortable bed
# 29  11        Food  Oh yeah the food is great to and very reasonab...
# 30  11    Location  The bus stop which goes to and from the airpor...
# 32  11        Room  The rooms are spacious and clean great to stay...
# 33  11       Staff  The staff here are amazing beyond expectations...
# 34  12        Food    The breakfast was lovely with room service too.
# 37  12        Room                        Very clean and comfortable.
# 38  12       Staff  The staff were exceptional. So helpful and fri...
# 39  13    Location  Short drive to the airport and very well locat...
# 41  13        Room  The rooms are lovely and new, very clean and c...
#
#                                           Text_output  Cosine_Similarity
# 0                                                 NaN           0.000000
# 1   Tasty food on the first floor, comfortable res...           1.000000
# 2          close to the airport, to very clean beach.           1.000000
# 5                        New, comfortable apartments.           0.000000
# 6   Staff is extremely helpful and easy to communi...           1.000000
# 7   the location is great and near the airport. bu...           1.000000
# 8                                 Great Quality/price           1.000000
# 9                                               Clean           1.000000
# 10                                        Great stuff           1.000000
# 11  in a very convenient location. An easy stroll ...           1.000000
# 12       Clean and modern with very comfortable beds.           1.000000
# 15  The room was exceptionally clean with a really...           1.000000
# 17                                          renovated           0.000000
# 18                                      nice location           1.000000
# 20                                    lovely personal           1.000000
# 21  couldn't eat breakfast due to dietary restrict...           0.000000
# 22       possibility of purchasing fresh fruit or veg           0.000000
# 25  very helpful host showed us how nearby bus tak...           0.706583
# 26                           no need for 21 euro taxi           0.000000
# 27                                    quiet location.           1.000000
# 28                 Great modern room comfortable bed.           1.000000
# 29   the food is great to and very reasonable prices.           0.731575
# 30  The bus stop which goes to and from the airpor...           1.000000
# 32  The rooms are spacious and clean great to stay...           0.860751
# 33  The staff here are amazing beyond expectations...           0.942063
# 34    The breakfast was lovely with room service too.           1.000000
# 37                        Very clean and comfortable.           1.000000
# 38  The staff were exceptional. So helpful and fri...           1.000000
# 39  Short drive to the airport and very well locat...           1.000000
# 41  The rooms are lovely and new, very clean and c...           1.000000

# %%
def isCorrect(row):
    # Case 1: If either the human-labeled text or the model output text is missing, mark as incorrect
    if pd.isna(row['Text_answer']) or pd.isna(row['Text_output']):
        return False
    # Case 2: If cosine similarity is missing (NaN), mark as incorrect
    if pd.isna(row['Cosine_Similarity']):
        return False
     # Case 3: If the cosine similarity is greater than or equal to 0.7, consider it correct
    return row['Cosine_Similarity'] >= 0.7

df_compare['IsCorrect'] = df_compare.apply(isCorrect, axis=1)

# Optional:
# Display the first 40 rows to review the following columns:
# - ID: Data point ID
# - Topics: Topic label
# - NegPos_answer: Human-labeled sentiment
# - NegPos_output: Model-predicted sentiment
# - Text_answer: Human-labeled text span
# - Text_output: Model-predicted text span
# - Cosine_Similarity: Similarity score between the texts
# - IsCorrect: Boolean flag indicating whether the extraction is correct based on the similarity threshold
df_compare[['ID', 'Topics', 'NegPos_answer', 'NegPos_output', 'Text_answer', 'Text_output', 'Cosine_Similarity', 'IsCorrect']].head(40)
# Out:
#     ID      Topics NegPos_answer NegPos_output  \
# 0    1    Facility      Positive           NaN
# 1    1        Food      Positive      Positive
# 2    1    Location      Positive      Positive
# 5    1        Room           NaN      Positive
# 6    1       Staff      Positive      Positive
# 7    3    Location      Positive      Positive
# 8    4       Price      Positive      Positive
# 9    4        Room      Positive      Positive
# 10   4       Staff      Positive      Positive
# 11   5    Location      Positive      Positive
# 12   5        Room      Positive      Positive
# 15   6        Room      Positive      Positive
# 17   8    Facility           NaN      Positive
# 18   8    Location      Positive      Positive
# 20   8       Staff      Positive      Positive
# 21   9        Food           NaN      Negative
# 22   9        Food           NaN      Positive
# 25   9       Staff      Positive      Positive
# 26   9  Taxi-issue           NaN      Positive
# 27  10    Location      Positive      Positive
# 28  10        Room      Positive      Positive
# 29  11        Food      Positive      Positive
# 30  11    Location      Positive      Positive
# 32  11        Room      Positive      Positive
# 33  11       Staff      Positive      Positive
# 34  12        Food      Positive      Positive
# 37  12        Room      Positive      Positive
# 38  12       Staff      Positive      Positive
# 39  13    Location      Positive      Positive
# 41  13        Room      Positive      Positive
# 42  13       Staff      Positive      Positive
# 43  14    Facility           NaN      Negative
# 44  14    Location           NaN      Negative
# 45  14    Location      Positive      Positive
# 48  14        Room      Negative           NaN
# 49  14       Staff      Negative      Negative
# 50  15    Location      Negative      Negative
# 51  15    Location      Positive      Positive
# 54  15       Staff      Positive      Positive
# 55  16        Food      Positive      Positive
#
#                                           Text_answer  \
# 0                         New, comfortable apartments
# 1   Tasty food on the first floor, comfortable res...
# 2          close to the airport, to very clean beach.
# 5                                                 NaN
# 6   Staff is extremely helpful and easy to communi...
# 7   the location is great and near the airport. bu...
# 8                                 Great Quality/price
# 9                                               Clean
# 10                                        Great stuff
# 11  in a very convenient location.  An easy stroll...
# 12        Clean and modern with very comfortable beds
# 15  The room was exceptionally clean with a really...
# 17                                                NaN
# 18                                      nice location
# 20                                    lovely personal
# 21                                                NaN
# 22                                                NaN
# 25  very helpful host showed us how nearby bus tak...
# 26                                                NaN
# 27                                     quiet location
# 28                  Great modern room comfortable bed
# 29  Oh yeah the food is great to and very reasonab...
# 30  The bus stop which goes to and from the airpor...
# 32  The rooms are spacious and clean great to stay...
# 33  The staff here are amazing beyond expectations...
# 34    The breakfast was lovely with room service too.
# 37                        Very clean and comfortable.
# 38  The staff were exceptional. So helpful and fri...
# 39  Short drive to the airport and very well locat...
# 41  The rooms are lovely and new, very clean and c...
# 42  The staff are so welcoming, we felt like stayi...
# 43                                                NaN
# 44                                                NaN
# 45  We wanted a hotel for a night that is close to...
# 48  You can hear the airplanes coming and leaving ...
# 49     The receptionist didn't speak English properly
# 50  it is a bit on the edge of Larnaca - with freq...
# 51  Chose really because it was reasonably close t...
# 54                                 The staff make it
# 55  The restaurant downstairs is amazing- the food...
#
#                                           Text_output  Cosine_Similarity  \
# 0                                                 NaN           0.000000
# 1   Tasty food on the first floor, comfortable res...           1.000000
# 2          close to the airport, to very clean beach.           1.000000
# 5                        New, comfortable apartments.           0.000000
# 6   Staff is extremely helpful and easy to communi...           1.000000
# 7   the location is great and near the airport. bu...           1.000000
# 8                                 Great Quality/price           1.000000
# 9                                               Clean           1.000000
# 10                                        Great stuff           1.000000
# 11  in a very convenient location. An easy stroll ...           1.000000
# 12       Clean and modern with very comfortable beds.           1.000000
# 15  The room was exceptionally clean with a really...           1.000000
# 17                                          renovated           0.000000
# 18                                      nice location           1.000000
# 20                                    lovely personal           1.000000
# 21  couldn't eat breakfast due to dietary restrict...           0.000000
# 22       possibility of purchasing fresh fruit or veg           0.000000
# 25  very helpful host showed us how nearby bus tak...           0.706583
# 26                           no need for 21 euro taxi           0.000000
# 27                                    quiet location.           1.000000
# 28                 Great modern room comfortable bed.           1.000000
# 29   the food is great to and very reasonable prices.           0.731575
# 30  The bus stop which goes to and from the airpor...           1.000000
# 32  The rooms are spacious and clean great to stay...           0.860751
# 33  The staff here are amazing beyond expectations...           0.942063
# 34    The breakfast was lovely with room service too.           1.000000
# 37                        Very clean and comfortable.           1.000000
# 38  The staff were exceptional. So helpful and fri...           1.000000
# 39  Short drive to the airport and very well locat...           1.000000
# 41  The rooms are lovely and new, very clean and c...           1.000000
# 42  The staff are so welcoming, we felt like stayi...           1.000000
# 43  you have a feeling that people are living in t...           0.000000
# 44  You can hear the airplanes coming and leaving ...           0.000000
# 45  close to the airport and this hotel did that p...           0.912616
# 48                                                NaN           0.000000
# 49    The receptionist didn't speak English properly.           1.000000
# 50                 it is a bit on the edge of Larnaca           0.702835
# 51  reasonably close to the Airport for an early m...           0.743278
# 54  The staff make it - particularly reception and...           0.558701
# 55  The restaurant downstairs is amazing- the food...           1.000000
#
#     IsCorrect
# 0       False
# 1        True
# 2        True
# 5       False
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 15       True
# 17      False
# 18       True
# 20       True
# 21      False
# 22      False
# 25       True
# 26      False
# 27       True
# 28       True
# 29       True
# 30       True
# 32       True
# 33       True
# 34       True
# 37       True
# 38       True
# 39       True
# 41       True
# 42       True
# 43      False
# 44      False
# 45       True
# 48      False
# 49       True
# 50       True
# 51       True
# 54      False
# 55       True

# %%
df_compare.to_csv('output_cosine_Dataset2_5_shot_3.csv', index=False)

print("CSV saved successfully")
# Out:
# CSV saved successfully

# %%
eval_list = []

for id_val in sorted(df_compare['ID'].unique()):
    df_id = df_compare[df_compare['ID'] == id_val]

    num_preds = df_id['Text_output'].notna().sum()  # Model output per ID
    num_ans = df_id['Text_answer'].notna().sum()    # Ground truth per ID
    num_correct = df_id['IsCorrect'].sum()           # Correct cosine matches

    # Precision = Correct Predictions / Total Predictions
    precision = num_correct / num_preds if num_preds > 0 else 0
    # Recall = Correct Predictions / Total Answers
    recall = num_correct / num_ans if num_ans > 0 else 0

    # Append results as a dictionary into eval_list
    eval_list.append({
        'ID': id_val,               # Current ID
        'pre_nom': num_correct,     # Numerator for Precision (True Positives)
        'pre_denom': num_preds,     # Denominator for Precision (Model outputs)
        'Precision': precision,     
        're_nom': num_correct,      # Numerator for Recall (True Positives)
        're_denom': num_ans,        # Denominator for Recall (Human annotations)
        'Recall': recall
    })


eval_df = pd.DataFrame(eval_list).sort_values('ID').reset_index(drop=True)


eval_df.head(30)
# Out:
#     ID  pre_nom  pre_denom  Precision  re_nom  re_denom    Recall
# 0    1        3          4   0.750000       3         4  0.750000
# 1    3        1          1   1.000000       1         1  1.000000
# 2    4        3          3   1.000000       3         3  1.000000
# 3    5        2          2   1.000000       2         2  1.000000
# 4    6        1          1   1.000000       1         1  1.000000
# 5    8        2          3   0.666667       2         2  1.000000
# 6    9        1          4   0.250000       1         1  1.000000
# 7   10        2          2   1.000000       2         2  1.000000
# 8   11        4          4   1.000000       4         4  1.000000
# 9   12        3          3   1.000000       3         3  1.000000
# 10  13        3          3   1.000000       3         3  1.000000
# 11  14        2          4   0.500000       2         3  0.666667
# 12  15        2          3   0.666667       2         3  0.666667
# 13  16        2          2   1.000000       2         2  1.000000
# 14  17        2          2   1.000000       2         2  1.000000
# 15  19        1          1   1.000000       1         1  1.000000
# 16  20        1          2   0.500000       1         2  0.500000
# 17  22        3          6   0.500000       3         5  0.600000
# 18  23        1          1   1.000000       1         1  1.000000
# 19  24        1          1   1.000000       1         1  1.000000
# 20  25        1          1   1.000000       1         1  1.000000
# 21  26        4          6   0.666667       4         4  1.000000
# 22  27        3          3   1.000000       3         3  1.000000
# 23  28        2          2   1.000000       2         2  1.000000
# 24  30        3          3   1.000000       3         3  1.000000
# 25  31        4          4   1.000000       4         4  1.000000
# 26  32        2          2   1.000000       2         2  1.000000
# 27  34        2          4   0.500000       2         3  0.666667
# 28  35        0          1   0.000000       0         1  0.000000
# 29  36        4          5   0.800000       4         7  0.571429

# %%
# Save to CSV
eval_df.to_csv("evaluation_result_5_shot_3.csv", index=False)

print("Evaluation results saved to .csv")
# Out:
# Evaluation results saved to .csv

# %%
macro_precision = eval_df['Precision'].mean()
macro_recall = eval_df['Recall'].mean()

print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro Recall: {macro_recall:.4f}")
# Out:
# Macro Precision: 0.8158
# Macro Recall: 0.8359
