# %%
# AIzaSyAmpm7b3R8jGzjBFIQ-9lvlmhpbyw9lK1Y

# %%
pip install google-generativeai

# %%
import pandas as pd
import json
import google.generativeai as genai

genai.configure(api_key="YOUR API KEY HERE")  # Replace with your actual API key
model = genai.GenerativeModel("gemini-2.5-pro")

# ---------- Load Dataset ----------
file_path = '/Users/nonny/Downloads/Remove Disagreement Version(2).xlsx'  # Change to your file path
df = pd.read_excel(file_path)

df = df.rename(columns={'Column1': 'ID'})

df_positive = df[['ID', 'PositiveReview']].rename(columns={'PositiveReview': 'Review'})
df_negative = df[['ID', 'NegativeReview']].rename(columns={'NegativeReview': 'Review'})

df_positive = df_positive[df_positive['Review'].notna() & (df_positive['Review'].str.strip() != "")]
df_negative = df_negative[df_negative['Review'].notna() & (df_negative['Review'].str.strip() != "")]

df_positive = df_positive.drop_duplicates()
df_negative = df_negative.drop_duplicates()

df_combined = pd.concat([df_positive, df_negative], ignore_index=True)
df_combined = df_combined.sort_values(by=['ID']).reset_index(drop=True)

# %%
def build_full_prompt(messages):
    return "\n\n".join([f"{m['role'].capitalize()}: {m['content']}" for m in messages])

def parse_response(response_json, review_id, full_prompt):
    results = []
    try:
        cleaned = response_json.strip()
        if cleaned.startswith("```json"): cleaned = cleaned[7:]
        if cleaned.startswith("```"): cleaned = cleaned[3:]
        if cleaned.endswith("```"): cleaned = cleaned[:-3]
        cleaned = cleaned.strip()

        parsed = json.loads(cleaned)
        topics_list = parsed["Topics"]
        for topic_group in topics_list:
            for topic, entries in topic_group.items():
                for entry in entries:
                    results.append({
                        "ID": review_id,
                        "FullPrompt": full_prompt,
                        "Topics": topic,
                        "Text": entry.get("text") or "",
                        "NegPos": entry.get("label") or ""
                    })
    except Exception as e:
        print(f"Failed to parse response for ID {review_id}: {e}")
    return results

# %%
# Zero shot (Use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": review_text}
    ]

    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# --------------- Run all rows ----------------
final_results = []

for idx, row in df_combined.iterrows():
    review_text = row['Review']
    review_id = row['ID']
    print(f"Processing review ID {review_id}...")

    try:
        response_content, full_prompt = send_prompt(review_text)
        print(f"Raw response for ID {review_id}:\n{response_content}\n")

        review_results = parse_response(response_content, review_id, full_prompt)
        final_results.extend(review_results)

    except Exception as e:
        print(f"Error processing ID {review_id}: {e}")

# Save to CSV
output_df = pd.DataFrame(final_results)
output_csv_path = 'ABA_dataset_2_gemini_2.5_pro_0_shot_1.csv'
output_df.to_csv(output_csv_path, index=False)

print(" Done! Output saved.")

# %%
# One shot (use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
        {
            "role": "user",
            "content": "The room is enough big. But the room was a little bit dirty."
        },
        {
            "role": "assistant",
            "content": '{"Topics":[{"Room1":[{"text": "The room is enough big.","label": "Positive"}],'
                       '"Room2":[{"text": "the room was a little bit dirty.","label": "Negative"}],'
                       '"Staff":[{"text": null,"label": null}],'
                       '"Location":[{"text": null,"label": null}],'
                       '"Food":[{"text": null,"label": null}],'
                       '"Price":[{"text": null,"label": null}],'
                       '"Facility":[{"text": null,"label": null}],'
                       '"Check-in":[{"text": null,"label": null}],'
                       '"Check-out":[{"text": null,"label": null}],'
                       '"Taxi-issue":[{"text": null,"label": null}],'
                       '"Booking-issue":[{"text": null,"label": null}],'
                       '"Off":[{"text": null,"label": null}]}]}'
        },
        {
            "role": "user",
            "content": review_text,
        }
    ]

    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# ----------- Run for ALL rows -------------
for run_num in range(1, 4):  # 1 to 3
    final_results = []

    for idx, row in df_combined.iterrows():
        review_text = row['Review']
        review_id = row['ID']
        
        print(f"[Run {run_num}] Processing review ID {review_id}...")

        try:
            response_content, full_prompt = send_prompt(review_text)
            print(f"[Run {run_num}] Raw response for ID {review_id}:\n{response_content}\n")
            
            review_results = parse_response(response_content, review_id, full_prompt)
            final_results.extend(review_results)

        except Exception as e:
            print(f"[Run {run_num}] Error processing ID {review_id}: {e}")

    # Save results
    output_df = pd.DataFrame(final_results)
    output_csv_path = f'ABA_dataset_2_gemini_2.5_pro_1_shot_{run_num}.csv'
    output_df.to_csv(output_csv_path, index=False)
    print(f" Done! Results saved to {output_csv_path}")

# %%
# two shot (use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
    
        # Example 1
        {"role": "user", "content": "The room is enough big. But the room was a little bit dirty."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room is enough big.","label": "Positive"}],'
                                         '"Room2":[{"text": "the room was a little bit dirty.","label": "Negative"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Price":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },
    
        # Example 2
        {"role": "user", "content": "The room was very clean, well decorated and modern, although not big. It was cheap."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room was very clean, well decorated and modern","label": "Positive"}],'
                                         '"Room2":[{"text": "although not big","label": "Negative"}],'
                                         '"Price":[{"text": "cheap","label": "Positive"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },
    
        # Real input
        {"role": "user", "content": review_text}
    ]


    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# ----------- Run for ALL rows -------------
for run_num in range(1, 4):  # 1 to 3
    final_results = []

    for idx, row in df_combined.iterrows():
        review_text = row['Review']
        review_id = row['ID']
        
        print(f"[Run {run_num}] Processing review ID {review_id}...")

        try:
            response_content, full_prompt = send_prompt(review_text)
            print(f"[Run {run_num}] Raw response for ID {review_id}:\n{response_content}\n")
            
            review_results = parse_response(response_content, review_id, full_prompt)
            final_results.extend(review_results)

        except Exception as e:
            print(f"[Run {run_num}] Error processing ID {review_id}: {e}")

    # Save results
    output_df = pd.DataFrame(final_results)
    output_csv_path = f'ABA_dataset_2_gemini_2.5_pro_2_shot_{run_num}.csv'
    output_df.to_csv(output_csv_path, index=False)
    print(f" Done! Results saved to {output_csv_path}")

# %%
# three shot (use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
    
        # Example 1
        {"role": "user", "content": "The room is enough big. But the room was a little bit dirty."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room is enough big.","label": "Positive"}],'
                                         '"Room2":[{"text": "the room was a little bit dirty.","label": "Negative"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Price":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },
    
        # Example 2
        {"role": "user", "content": "The room was very clean, well decorated and modern, although not big. It was cheap."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room was very clean, well decorated and modern","label": "Positive"}],'
                                         '"Room2":[{"text": "although not big","label": "Negative"}],'
                                         '"Price":[{"text": "cheap","label": "Positive"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },

        # Example 3
        {"role": "user", "content": "Location. The hotel was new and close to the airport, which made traveling easy. However, there was a lot of street noise outside the window. Staff. The receptionist was polite and friendly. However, check-in took longer than expected. The hotel lobby was welcoming and spacious. The room had a comfortable bed, but the air conditioning was loud at night. The neighbors were noisy through the walls, and the WiFi in the room was weak and unreliable. The breakfast buffet was delicious; however, the coffee was terrible. The price was reasonable for the quality. The building was charming with historical architecture."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room had a comfortable bed.","label": "Positive"}],'
                               '"Room2":[{"text": "The air conditioning was loud at night.","label": "Negative"}],'
                               '"Room3":[{"text": "The neighbors were noisy through the walls.","label": "Negative"}],'
                               '"Room4":[{"text": "the WiFi in the room was weak and unreliable.","label": "Negative"}],'
                               '"Staff":[{"text": "The receptionist was polite and friendly.","label": "Positive"}],'
                               '"Location1":[{"text": "close to the airport, which made traveling easy.","label": "Positive"}],'
                               '"Location2":[{"text": "there was a lot of street noise outside the window.","label": "Negative"}],'
                               '"Food1":[{"text": "The breakfast buffet was delicious.","label": "Positive"}],'
                               '"Food2":[{"text": "the coffee was terrible.","label": "Negative"}],'
                               '"Price":[{"text": "The price was reasonable for the quality.","label": "Positive"}],'
                               '"Facility1":[{"text": "The hotel was new.","label": "Positive"}],'
                               '"Facility2":[{"text": "The hotel lobby was welcoming and spacious.","label": "Positive"}],'
                               '"Facility3":[{"text": "The building was charming with historical architecture.","label": "Positive"}],'
                               '"Check-in":[{"text": "check-in took longer than expected.","label": "Negative"}],'
                               '"Check-out":[{"text": null,"label": null}],'
                               '"Taxi-issue":[{"text": null,"label": null}],'
                               '"Booking-issue":[{"text": null,"label": null}],'
                               '"Off":[{"text": "Location. Staff.","label": null}]}]}'
        },
    
        # Real input
        {"role": "user", "content": review_text}
    ]


    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# ----------- Run for ALL rows -------------
for run_num in range(1, 2):  # 1 to 3
    final_results = []

    for idx, row in df_combined.iterrows():
        review_text = row['Review']
        review_id = row['ID']
        
        print(f"[Run {run_num}] Processing review ID {review_id}...")

        try:
            response_content, full_prompt = send_prompt(review_text)
            print(f"[Run {run_num}] Raw response for ID {review_id}:\n{response_content}\n")
            
            review_results = parse_response(response_content, review_id, full_prompt)
            final_results.extend(review_results)

        except Exception as e:
            print(f"[Run {run_num}] Error processing ID {review_id}: {e}")

    # Save results
    output_df = pd.DataFrame(final_results)
    output_csv_path = f'ABA_dataset_2_gemini_2.5_pro_3_shot_{run_num}.csv'
    output_df.to_csv(output_csv_path, index=False)
    print(f" Done! Results saved to {output_csv_path}")
# Out:
# [Run 1] Processing review ID 1...
# [Run 1] Raw response for ID 1:
# {"Topics":[{"Room":[{"text": "comfortable apartments","label": "Positive"}],"Staff":[{"text": "Staff is extremely helpful and easy to communicate with","label": "Positive"}],"Location":[{"text": "close to the airport, to very clean beach.","label": "Positive"}],"Food":[{"text": "Tasty food on the first floor","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "New, apartments, comfortable restaurant for both cozy evenings and calm work to escape the heat in the midday","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 1...
# [Run 1] Raw response for ID 1:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Nothing at all.","label": "Negative"}]}]}
#
# [Run 1] Processing review ID 3...
# [Run 1] Raw response for ID 3:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "the location is great and near the airport. bus stop is very close.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 4...
# [Run 1] Raw response for ID 4:
# {"Topics":[{"Room":[{"text": "Clean","label": "Positive"}],"Staff":[{"text": "Great stuff","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": "Great Quality/price","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 5...
# [Run 1] Raw response for ID 5:
# {"Topics":[{"Room":[{"text": "Clean and modern with very comfortable beds,","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "in a very convenient location. An easy stroll to numerous nice restaurants and a great beach.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 6...
# [Run 1] Raw response for ID 6:
# {"Topics":[{"Room":[{"text": "The room was exceptionally clean with a really comfortable bed","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "We only stayed over night before heading to the airport.","label": null}]}]}
#
# [Run 1] Processing review ID 7...
# [Run 1] Raw response for ID 7:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "great","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 8...
# [Run 1] Raw response for ID 8:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "lovely personal","label": "Positive"}],"Location":[{"text": "nice location","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "renovated","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 8...
# [Run 1] Raw response for ID 8:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "nothing","label": null}]}]}
#
# [Run 1] Processing review ID 9...
# [Run 1] Raw response for ID 9:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "very helpful host","label": "Positive"}],"Location":[{"text": "nearby bus takes to town-cntre (and airport by the way)","label": "Positive"}],"Food":[{"text": "couldn't eat breakfast due to dietary restrictions","label": "Negative"}],"Price":[{"text": "no need for 21 euro taxi","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 9...
# [Run 1] Raw response for ID 9:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": "maybe possibility of purchasing fresh fruit or veg","label": "Negative"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 10...
# [Run 1] Raw response for ID 10:
# {"Topics":[{"Room":[{"text": "Great modern room comfortable bed","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "quiet location.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 11...
# [Run 1] Raw response for ID 11:
# {"Topics":[{"Room":[{"text": "The rooms are spacious and clean great to stay .. I even got an upgrade which is always so nice.","label": "Positive"}],"Staff":[{"text": "The staff here are amazing beyond expectations..***** Maria at reception is just great she really took time to explain where to go how to get there and so helpful ... 🙏 Richard the chef this guy is like the friendliest guy ever, such a nice guy with a permanent. Smile 😁 Even the cleaning lady is so friendly and so nice to talk to . The owners are also great it's like a real caring family set up ...","label": "Positive"}],"Location":[{"text": "The bus stop which goes to and from the airport as well as the town center is a minutes walk away and just 2 euros","label": "Positive"}],"Food":[{"text": "the food is great","label": "Positive"}],"Price":[{"text": "very reasonable prices","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "My second time here and true to say it was better than the first which was excellent.. I don't think I need to mention where I'll be staying next time I'm in Larnaka.. 😊 Brilliant guys ... 🙏🙏🙏","label": null}]}]}
#
# [Run 1] Processing review ID 12...
# [Run 1] Raw response for ID 12:
# {"Topics":[{"Room":[{"text": "Very clean and comfortable.","label": "Positive"}],"Staff":[{"text": "The staff were exceptional. So helpful and friendly. Went out of their way for us.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": "The breakfast was lovely with room service too.","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 12...
# [Run 1] Raw response for ID 12:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Couldn’t stay longer","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 13...
# [Run 1] Raw response for ID 13:
# {"Topics":[{"Room":[{"text": "The rooms are lovely and new, very clean and comfortable. The mattress was to my taste.","label": "Positive"}],"Staff":[{"text": "The staff are so welcoming, we felt like staying with family.","label": "Positive"}],"Location":[{"text": "Short drive to the airport and very well located, just a short walk from the promenade, coffee shops restaurants.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 14...
# [Run 1] Raw response for ID 14:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "The receptionist didn't speak English properly","label": "Negative"}],"Location":[{"text": "You can hear the airplanes coming and leaving from the airport all the time","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "you have a feeling that people are living in the hotel, rather than staying at a hotel.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 14...
# [Run 1] Raw response for ID 14:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "close to the airport and this hotel did that purpose more than fair. There are some restaurants and bars next to the beach just 10min of walking distance from the hotel.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 15...
# [Run 1] Raw response for ID 15:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "The staff make it - particularly reception and the dining room.","label": "Positive"}],"Location":[{"text": "it was reasonably close to the Airport for an early morning flight, yet could have a stroll along the nearby beach.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Second visit","label": null}]}]}
#
# [Run 1] Processing review ID 15...
# [Run 1] Raw response for ID 15:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location1":[{"text": "with frequent busses to the centre.","label": "Positive"}],"Location2":[{"text": "it is a bit on the edge of Larnaca","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Nothing really, though for a stay for more than a few days","label": null}]}]}
#
# [Run 1] Processing review ID 16...
# [Run 1] Raw response for ID 16:
# {"Topics":[{"Room":[{"text": "I liked the rooms- they are spacious, clean, the window view is nice too.","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": "The restaurant downstairs is amazing- the food there is very very tasty and made with a lot of care- they care a lot about the details: olive oil galore, herbs- absolutely delicious!","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 17...
# [Run 1] Raw response for ID 17:
# {"Topics":[{"Room":[{"text": "Our room had a balcony with great view of the sea and surrounding area.","label": "Positive"}],"Staff":[{"text": "The owner and staff were exceptionally friendly and supportive and helped with all our wishes.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 17...
# [Run 1] Raw response for ID 17:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "-","label": null}]}]}
#
# [Run 1] Processing review ID 19...
# [Run 1] Raw response for ID 19:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Close to airport","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 20...
# [Run 1] Raw response for ID 20:
# {"Topics":[{"Room":[{"text": "clean","label": "Positive"}],"Staff":[{"text": "friendly stuff","label": "Positive"}],"Location":[{"text": "location","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 22...
# [Run 1] Raw response for ID 22:
# {"Topics":[{"Room1":[{"text": "Room was perfect, looked new, clean shiny tiled floors and bathroom tiles, just every inch perfect and clean. Bed was really comfortable, lots of room for me to put my things...","label": "Positive"}],"Room2":[{"text": "although might have needed another set of drawers if there were two of us.","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 22...
# [Run 1] Raw response for ID 22:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "the staff very accomodating.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": "Ordered pizza one night and was not great, too stodgy","label": "Negative"}],"Price":[{"text": null,"label": null}],"Facility1":[{"text": "When you left it running for around 5 mins it got warm and was a good shower. The restaurant area is nice","label": "Positive"}],"Facility2":[{"text": "Fridge could have been put on beforehand so it was cold, the shower took a while to get hot, had to have a cold shower one morning as i needed to get out early.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 23...
# [Run 1] Raw response for ID 23:
# {"Topics":[{"Room":[{"text": "the beds were very comfortable","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 24...
# [Run 1] Raw response for ID 24:
# {"Topics":[{"Room":[{"text": "I loved the mattress!!!","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 25...
# [Run 1] Raw response for ID 25:
# {"Topics":[{"Room":[{"text": "Clean and quiet","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 26...
# [Run 1] Raw response for ID 26:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": "Leaving..in fact just re booked the hotel for 2 weeks time 😁","label": "Positive"}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 26...
# [Run 1] Raw response for ID 26:
# {"Topics":[{"Room":[{"text": "The rooms are a good size and are laid out very well with a good size bathroom The room also has a great sized balcony to take a tea/coffee and chill","label": "Positive"}],"Staff":[{"text": "The staff are super wonderful really friendly all of them the receptionist Maria is so nice she's amazing","label": "Positive"}],"Location":[{"text": "The hotel is 5 minutes from the beach and the location is also near the lake.","label": "Positive"}],"Food":[{"text": "the food is good","label": "Positive"}],"Price":[{"text": "not to pricey.","label": "Positive"}],"Facility":[{"text": "There is a great restaurant inside","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Keep up the great work 👍🏼🙏","label": null}]}]}
#
# [Run 1] Processing review ID 27...
# [Run 1] Raw response for ID 27:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "nothing.","label": null}]}]}
#
# [Run 1] Processing review ID 27...
# [Run 1] Raw response for ID 27:
# {"Topics":[{"Room":[{"text": "so comfortable, clean","label": "Positive"}],"Staff":[{"text": "friendly staff.","label": "Positive"}],"Location":[{"text": "perfect for overnight stay before flying from Larnaca Airport.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 28...
# [Run 1] Raw response for ID 28:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Surrounding buildings are under construction and poorly lit.","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 28...
# [Run 1] Raw response for ID 28:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "Staff is very polite and caring.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Thank you","label": null}]}]}
#
# [Run 1] Processing review ID 30...
# [Run 1] Raw response for ID 30:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Not applicable","label": null}]}]}
#
# [Run 1] Processing review ID 30...
# [Run 1] Raw response for ID 30:
# {"Topics":[{"Room":[{"text": "The room was spotless.","label": "Positive"}],"Staff":[{"text": "Staff were lovely. Service was great.","label": "Positive"}],"Location":[{"text": "Great location for restaurants. Great location for a short drive to the airport.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 31...
# [Run 1] Raw response for ID 31:
# {"Topics":[{"Room":[{"text": "Clean, comfortable","label": "Positive"}],"Staff":[{"text": "friendly staff.","label": "Positive"}],"Location":[{"text": "Very close to Mackenzy beach & Larnaca airport.","label": "Positive"}],"Food":[{"text": "food excellent","label": "Positive"}],"Price":[{"text": "reasonably priced.","label": "Positive"}],"Facility":[{"text": "Great restaurant beneath the hotel","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "We would definitely stay there again","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 31...
# [Run 1] Raw response for ID 31:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "All good","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 32...
# [Run 1] Raw response for ID 32:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Nothing.","label": null}]}]}
#
# [Run 1] Processing review ID 32...
# [Run 1] Raw response for ID 32:
# {"Topics":[{"Room":[{"text": "The bed was great. Rooms clean.","label": "Positive"}],"Staff":[{"text": "Staff were so kind.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 34...
# [Run 1] Raw response for ID 34:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "welcoming","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": "value for money","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "location","label": null}]}]}
#
# [Run 1] Processing review ID 34...
# [Run 1] Raw response for ID 34:
# {"Topics":[{"Room":[{"text": "more hooks on walls for towels etc.","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 35...
# [Run 1] Raw response for ID 35:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "There was a problem with heating water at that time and we can understand, but eventually we couldn't manage to have a proper shower with hot water.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 36...
# [Run 1] Raw response for ID 36:
# {"Topics":[{"Room1":[{"text": "I had no problem as they were very clean, and the bed was really comfortable.","label": "Positive"}],"Room2":[{"text": "The room was smaller than I expected","label": "Negative"}],"Staff":[{"text": "The receptionist on check in was very good and explained the information very clearly to us. The chef was very polite","label": "Positive"}],"Location":[{"text": "the location in a small side street, but it was only a 10-minute walk to the sea front.","label": "Positive"}],"Food":[{"text": "his food was excellent, he had passion and it showed in his presentation.","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "there was no opening and closing times of the bar on display.","label": "Negative"}],"Check-in":[{"text": "check in was very good and explained the information very clearly to us.","label": "Positive"}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 36...
# [Run 1] Raw response for ID 36:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "not showing opening times.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Nothing except","label": null}]}]}
#
# [Run 1] Processing review ID 38...
# [Run 1] Raw response for ID 38:
# {"Topics":[{"Room":[{"text": "great rooms - nice and cool","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 39...
# [Run 1] Raw response for ID 39:
# {"Topics":[{"Room":[{"text": "It was really clean and spacious","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 40...
# [Run 1] Raw response for ID 40:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Nice location, not far from Airport and Mackenzie beach.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 40...
# [Run 1] Raw response for ID 40:
# {"Topics":[{"Room":[{"text": "there was no net curtain or blind so one needed to ensure that the curtain was closed, especially when going for a shower as the room is opposite some apartments that have a clear view into the room!","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 41...
# [Run 1] Raw response for ID 41:
# {"Topics":[{"Room":[{"text": "Clean modern rooms","label": "Positive"}],"Staff":[{"text": "Super friendly and helpful staff.","label": "Positive"}],"Location":[{"text": "A good location 5 lins away from the airport by car, 5 mins walk to the beach.","label": "Positive"}],"Food":[{"text": "very nice breakfast.","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 41...
# [Run 1] Raw response for ID 41:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "I would just flag that ahead of time in the welcome email to those arriving from the UK","label": "Negative"}],"Location":[{"text": null,"label": null}],"Food":[{"text": "the kitchen shuts at 22:30 or so, and there is no food to be had afterwards. ... have something like nuts / chips available to buy on arrival.","label": "Negative"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 42...
# [Run 1] Raw response for ID 42:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "hospitality","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 42...
# [Run 1] Raw response for ID 42:
# {"Topics":[{"Room":[{"text": "clean","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 43...
# [Run 1] Raw response for ID 43:
# {"Topics":[{"Room":[{"text": "clean spacious practical","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 45...
# [Run 1] Raw response for ID 45:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "The beach is about 5 minutes walk away.","label": "Positive"}],"Food":[{"text": "good food","label": "Positive"}],"Price":[{"text": "very reasonably priced","label": "Positive"}],"Facility":[{"text": "Recently updated, everything was me and clean. Restaurant was a surprise hit","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 45...
# [Run 1] Raw response for ID 45:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location1":[{"text": "There is a bit of plane noise in the afternoon and evening because it is right near the takeoff end of the runway","label": "Negative"}],"Location2":[{"text": "but next to no departures in the morning, so not a problem","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 46...
# [Run 1] Raw response for ID 46:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": "Great value for money","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 47...
# [Run 1] Raw response for ID 47:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "very helpful staff who organised a taxi to collect us in the morning.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": "Good value for money.","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 48...
# [Run 1] Raw response for ID 48:
# {"Topics":[{"Room":[{"text": "Clean and comfortable rooms","label": "Positive"}],"Staff":[{"text": "lovely owner","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 49...
# [Run 1] Raw response for ID 49:
# {"Topics":[{"Room":[{"text": "The 2 rooms were big enough for a family of 5.","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Great location close to the airport and a short walk to the sea.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": "Great value for money.","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 50...
# [Run 1] Raw response for ID 50:
# {"Topics":[{"Room":[{"text": "Not very Soundproof","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 50...
# [Run 1] Raw response for ID 50:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "close to airport","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "Great little hotel","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 52...
# [Run 1] Raw response for ID 52:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Nothing","label": null}]}]}
#
# [Run 1] Processing review ID 52...
# [Run 1] Raw response for ID 52:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Everything was good❤❤❤❤","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 53...
# [Run 1] Raw response for ID 53:
# {"Topics":[{"Room":[{"text": "comfortable bed","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "close to the airport and Mackenzie Beach","label": "Positive"}],"Food":[{"text": "delicious breakfasts in the hotel restaurant","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "nice, renovated hotel","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 54...
# [Run 1] Raw response for ID 54:
# {"Topics":[{"Room":[{"text": "Very nice and clean room.","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 55...
# [Run 1] Raw response for ID 55:
# {"Topics":[{"Room":[{"text": "A lot of mosquitos","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 55...
# [Run 1] Raw response for ID 55:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Good for airport transfers","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 56...
# [Run 1] Raw response for ID 56:
# {"Topics":[{"Room":[{"text": "beds are extremely comfortable","label": "Positive"}],"Staff":[{"text": "amazing hospitality from the staff.","label": "Positive"}],"Location":[{"text": "Perfect place to stay for early morning / late night flights as it’s situated within 5 minutes from the airport.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 56...
# [Run 1] Raw response for ID 56:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "prime location near the airport","label": "Positive"}],"Food":[{"text": "it would’ve been great if breakfast started at 7 rather than 8.","label": "Negative"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "everything was perfect for one nights stay.","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 57...
# [Run 1] Raw response for ID 57:
# {"Topics":[{"Room":[{"text": "Very clean, very comfortable room.","label": "Positive"}],"Staff":[{"text": "Staff was extremely helpful. They ordered a taxi for us to get to the airport very early in the morning.","label": "Positive"}],"Location":[{"text": "We were able to enjoy a very nice, short walk to the beach where there were many restaurants available to choose from.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "We will definitely stay here again when we come back to Larnaca.","label": "Positive"}]}]}
#
# [Run 1] Processing review ID 58...
# [Run 1] Raw response for ID 58:
# ...
#
# [Run 1] Processing review ID 765...
# [Run 1] Raw response for ID 765:
# {"Topics":[{"Room":[{"text": "Very comfortable bed.","label": "Positive"}],"Staff":[{"text": "Excellent attention.","label": "Positive"}],"Location":[{"text": "Bars and restaurants nearby.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "Very good shower. The furniture and bathroom are all new and impeccable. Very good WiFi connection.","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 765...
# [Run 1] Raw response for ID 765:
# {"Topics":[{"Room":[{"text": "The balcony on the first floor is very low, not very intimate, close to the street and the hotel lobby, you can even smell the smoke from the cigarettes that smoke there. They could put shampoo in the bathroom, not just soap. Since there is a kettle and the room ers for two people, they could put 2 coffee sachets and 2 tea sachets, not just 1.","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "The safe does not make sense since it is not walled, it does not matter if you leave the money in a bag.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": "In the photo of the room on Booking, you can't see a column that takes up space and is uncomfortable.","label": "Negative"}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 766...
# [Run 1] Raw response for ID 766:
# {"Topics":[{"Room":[{"text": "small corner","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": "The room given was not the one booked.","label": "Negative"}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 766...
# [Run 1] Raw response for ID 766:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "Cleanliness","label": null}]}]}
#
# [Run 1] Processing review ID 767...
# [Run 1] Raw response for ID 767:
# {"Topics":[{"Room":[{"text": "The windows overlooked the courtyard, where it was quite noisy.","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Far from the beach.","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": "400 euros for 3 nights a bit expensive.","label": "Negative"}],"Facility":[{"text": "The hotel is average (3 stars)","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 767...
# [Run 1] Raw response for ID 767:
# {"Topics":[{"Room":[{"text": "Clean and spacious room","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 768...
# [Run 1] Raw response for ID 768:
# {"Topics":[{"Room":[{"text": "terrace in the room, well-furnished room and bathroom,","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "location of the object.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 768...
# [Run 1] Raw response for ID 768:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": "monotonous breakfasts (everyday the same set: 2 eggs, 2 slices of toast, 1/4 grilled mushroom, 1/2 grilled tomato, pepper, 2 small sausages, coffee)","label": "Negative"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "the relaxation zone (swimming pool, deckchairs, billiards) definitely did not encourage you to use it.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 769...
# [Run 1] Raw response for ID 769:
# {"Topics":[{"Room1":[{"text": "Bed linen was never changed. the number is microscopic. Rented Nissan Micra and then more. the refrigerator is full of minibar for money, I had to pull everything out so that my products would fit.","label": "Negative"}],"Room2":[{"text": "cleaning and change of towels daily","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "walk to the promenade of Larnaca for about 20 minutes, to Lidl for an hour and a half.","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": "the hotel did not allow to turn over a couple of hours before the delayed plane;","label": "Negative"}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "The hotel is really for one night.","label": "Negative"}]}]}
#
# [Run 1] Processing review ID 769...
# [Run 1] Raw response for ID 769:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "the beach is within walking distance. a couple of taverns in the area near the airport","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "cleanliness","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "A hotel for those who make a long transfer in Cyprus. That is \"hotel for one night\". Pros:","label": null}]}]}
#
# [Run 1] Processing review ID 770...
# [Run 1] Raw response for ID 770:
# {"Topics":[{"Room":[{"text": "lack of storage spaces","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "a constant stench coming from outside","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 770...
# [Run 1] Raw response for ID 770:
# {"Topics":[{"Room":[{"text": "Clean, daily change of towels","label": "Positive"}],"Staff":[{"text": "pleasant and helpful staff","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": "value for money","label": "Positive"}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 776...
# [Run 1] Raw response for ID 776:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "proximity to the airport, walk to the sea","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "Cleanliness","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 777...
# [Run 1] Raw response for ID 777:
# {"Topics":[{"Room":[{"text": "we changed the room from a one-room to a two-room with a balcony.","label": "Positive"}],"Staff":[{"text": "Responsive staff. Always with a smile.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": "Delicious breakfast options.","label": "Positive"}],"Price":[{"text": "inexpensive breakfast options.","label": "Positive"}],"Facility":[{"text": "Wonderful hotel with a cozy homely atmosphere.","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 780...
# [Run 1] Raw response for ID 780:
# {"Topics":[{"Room":[{"text": "nice room, large room size","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "location near mackenzie beach.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "Cozy hotel","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 780...
# [Run 1] Raw response for ID 780:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 781...
# [Run 1] Raw response for ID 781:
# {"Topics":[{"Room":[{"text": "Bed frame structure dangerous, sharp corners.","label": "Negative"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 781...
# [Run 1] Raw response for ID 781:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "A friendly, nice and sympathetic man serving breakfast.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 782...
# [Run 1] Raw response for ID 782:
# {"Topics":[{"Room":[{"text": "clean room","label": "Positive"}],"Staff":[{"text": null,"label": null}],"Location":[{"text": null,"label": null}],"Food":[{"text": "Delicious breakfast","label": "Positive"}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "excellent renovation with taste, stylish and beautiful!","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 783...
# [Run 1] Raw response for ID 783:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "Great staff ... great willingness!","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "The hotel itself was tidy and modern,","label": "Positive"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 784...
# [Run 1] Raw response for ID 784:
# {"Topics":[{"Room":[{"text": "very clean and new rooms.","label": "Positive"}],"Staff":[{"text": "Very friendly and warm service.","label": "Positive"}],"Location":[{"text": "Proximity to the beach and airport.","label": "Positive"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": null,"label": null}]}]}
#
# [Run 1] Processing review ID 785...
# [Run 1] Raw response for ID 785:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": "Very kind and helpful staff.","label": "Positive"}],"Location":[{"text": null,"label": null}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": null,"label": null}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": null,"label": null}],"Off":[{"text": "The stay is worth it only for sleeping before departure.","label": null}]}]}
#
# [Run 1] Processing review ID 785...
# [Run 1] Raw response for ID 785:
# {"Topics":[{"Room":[{"text": null,"label": null}],"Staff":[{"text": null,"label": null}],"Location":[{"text": "Bad-degraded area. Garbage heap in the bin next to the hotel.","label": "Negative"}],"Food":[{"text": null,"label": null}],"Price":[{"text": null,"label": null}],"Facility":[{"text": "Not as clean as it should be inside.","label": "Negative"}],"Check-in":[{"text": null,"label": null}],"Check-out":[{"text": null,"label": null}],"Taxi-issue":[{"text": null,"label": null}],"Booking-issue":[{"text": "Misleading photos.","label": "Negative"}],"Off":[{"text": null,"label": null}]}]}
#
#  Done! Results saved to ABA_dataset_2_gemini_2.5_pro_3_shot_1.csv

# %%
# four shot (use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
    
        # Example 1
        {"role": "user", "content": "The room is enough big. But the room was a little bit dirty."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room is enough big.","label": "Positive"}],'
                                         '"Room2":[{"text": "the room was a little bit dirty.","label": "Negative"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Price":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },
    
        # Example 2
        {"role": "user", "content": "The room was very clean, well decorated and modern, although not big. It was cheap."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room was very clean, well decorated and modern","label": "Positive"}],'
                                         '"Room2":[{"text": "although not big","label": "Negative"}],'
                                         '"Price":[{"text": "cheap","label": "Positive"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },

        # Example 3
        {"role": "user", "content": "Location. The hotel was new and close to the airport, which made traveling easy. However, there was a lot of street noise outside the window. Staff. The receptionist was polite and friendly. However, check-in took longer than expected. The hotel lobby was welcoming and spacious. The room had a comfortable bed, but the air conditioning was loud at night. The neighbors were noisy through the walls, and the WiFi in the room was weak and unreliable. The breakfast buffet was delicious; however, the coffee was terrible. The price was reasonable for the quality. The building was charming with historical architecture."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room had a comfortable bed.","label": "Positive"}],'
                               '"Room2":[{"text": "The air conditioning was loud at night.","label": "Negative"}],'
                               '"Room3":[{"text": "The neighbors were noisy through the walls.","label": "Negative"}],'
                               '"Room4":[{"text": "the WiFi in the room was weak and unreliable.","label": "Negative"}],'
                               '"Staff":[{"text": "The receptionist was polite and friendly.","label": "Positive"}],'
                               '"Location1":[{"text": "close to the airport, which made traveling easy.","label": "Positive"}],'
                               '"Location2":[{"text": "there was a lot of street noise outside the window.","label": "Negative"}],'
                               '"Food1":[{"text": "The breakfast buffet was delicious.","label": "Positive"}],'
                               '"Food2":[{"text": "the coffee was terrible.","label": "Negative"}],'
                               '"Price":[{"text": "The price was reasonable for the quality.","label": "Positive"}],'
                               '"Facility1":[{"text": "The hotel was new.","label": "Positive"}],'
                               '"Facility2":[{"text": "The hotel lobby was welcoming and spacious.","label": "Positive"}],'
                               '"Facility3":[{"text": "The building was charming with historical architecture.","label": "Positive"}],'
                               '"Check-in":[{"text": "check-in took longer than expected.","label": "Negative"}],'
                               '"Check-out":[{"text": null,"label": null}],'
                               '"Taxi-issue":[{"text": null,"label": null}],'
                               '"Booking-issue":[{"text": null,"label": null}],'
                               '"Off":[{"text": "Location. Staff.","label": null}]}]}'
        },

        # Example 4
        {"role": "user", "content": "location, service, overall was good, Sure worth it to come back again"},
        {"role": "assistant", "content": '{"Topics":[{"Room":[{"text": null,"label": null}],'
                                '"Staff":[{"text": null,"label": null}],'
                                '"Location":[{"text": null,"label": null}],'
                                '"Food":[{"text": null,"label": null}],'
                                '"Price":[{"text": null,"label": null}],'
                                '"Facility":[{"text": null,"label": null}],'
                                '"Check-in":[{"text": null,"label": null}],'
                                '"Check-out":[{"text": null,"label": null}],'
                                '"Taxi-issue":[{"text": null,"label": null}],'
                                '"Booking-issue":[{"text": null,"label": null}],'
                                '"Off":[{"text": "location, service, overall was good, Sure worth it to come back again","label": "Positive"}]}]}'
        },
    
        # Real input
        {"role": "user", "content": review_text}
    ]


    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# ----------- Run for ALL rows -------------
for run_num in range(1, 4):  # 1 to 3
    final_results = []

    for idx, row in df_combined.iterrows():
        review_text = row['Review']
        review_id = row['ID']
        
        print(f"[Run {run_num}] Processing review ID {review_id}...")

        try:
            response_content, full_prompt = send_prompt(review_text)
            print(f"[Run {run_num}] Raw response for ID {review_id}:\n{response_content}\n")
            
            review_results = parse_response(response_content, review_id, full_prompt)
            final_results.extend(review_results)

        except Exception as e:
            print(f"[Run {run_num}] Error processing ID {review_id}: {e}")

    # Save results
    output_df = pd.DataFrame(final_results)
    output_csv_path = f'ABA_dataset_2_gemini_2.5_pro_4_shot_{run_num}.csv'
    output_df.to_csv(output_csv_path, index=False)
    print(f" Done! Results saved to {output_csv_path}")

# %%
## five shot (use this)
def send_prompt(review_text):
    system_prompt = (
        'Please output the following [text] according to the [constraints] in the [output format].\n '
        '[constraints]* The output should only be in the [output format], and you must classify which part of the text corresponds to which Topic in the [Topics]. '
        'Additionally, determine whether each classified element is Positive or Negative. If there is no corresponding element, put Null for both `text` and `label`. '
        'The most important constraint is not to include any extra characters such as newline characters, `json`, or backticks, or any other unnecessary text outside of the [output format]. '
        'If there are two or more elements of the same Topic, number each so that they do not conflict when converted to json format data. '
        'However, if they have the same NegPos label, keep them in one Text as much as possible.* \n '
        '[Topics] Room, Staff, Location, Food, Price, Facility, Check-in, Check-out, Taxi-issue, Booking-issue, Off \n\n '
        '[output format] '
        '{"Topics":[{"Room":[{"text": "test","label": "Positive"}],'
        '"Staff":[{"text": null,"label": null}],'
        '"Location":[{"text": "test","label": "Positive"}],'
        '"Food":[{"text": "test","label": "Negative"}],'
        '"Price":[{"text": "test","label": "Positive"}],'
        '"Facility":[{"text": "test","label": "Negative"}],'
        '"Check-in":[{"text": "test","label": "Positive"}],'
        '"Check-out":[{"text": null,"label": null}],'
        '"Taxi-issue":[{"text": null,"label": null}],'
        '"Booking-issue":[{"text": null,"label": null}],'
        '"Off":[{"text": null,"label": null}]}]}'
    )

    messages = [
        {"role": "system", "content": system_prompt},
    
        # Example 1
        {"role": "user", "content": "The room is enough big. But the room was a little bit dirty."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room is enough big.","label": "Positive"}],'
                                         '"Room2":[{"text": "the room was a little bit dirty.","label": "Negative"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Price":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },
    
        # Example 2
        {"role": "user", "content": "The room was very clean, well decorated and modern, although not big. It was cheap."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room was very clean, well decorated and modern","label": "Positive"}],'
                                         '"Room2":[{"text": "although not big","label": "Negative"}],'
                                         '"Price":[{"text": "cheap","label": "Positive"}],'
                                         '"Staff":[{"text": null,"label": null}],'
                                         '"Location":[{"text": null,"label": null}],'
                                         '"Food":[{"text": null,"label": null}],'
                                         '"Facility":[{"text": null,"label": null}],'
                                         '"Check-in":[{"text": null,"label": null}],'
                                         '"Check-out":[{"text": null,"label": null}],'
                                         '"Taxi-issue":[{"text": null,"label": null}],'
                                         '"Booking-issue":[{"text": null,"label": null}],'
                                         '"Off":[{"text": null,"label": null}]}]}'
        },

        # Example 3
        {"role": "user", "content": "Location. The hotel was new and close to the airport, which made traveling easy. However, there was a lot of street noise outside the window. Staff. The receptionist was polite and friendly. However, check-in took longer than expected. The hotel lobby was welcoming and spacious. The room had a comfortable bed, but the air conditioning was loud at night. The neighbors were noisy through the walls, and the WiFi in the room was weak and unreliable. The breakfast buffet was delicious; however, the coffee was terrible. The price was reasonable for the quality. The building was charming with historical architecture."},
        {"role": "assistant", "content": '{"Topics":[{"Room1":[{"text": "The room had a comfortable bed.","label": "Positive"}],'
                               '"Room2":[{"text": "The air conditioning was loud at night.","label": "Negative"}],'
                               '"Room3":[{"text": "The neighbors were noisy through the walls.","label": "Negative"}],'
                               '"Room4":[{"text": "the WiFi in the room was weak and unreliable.","label": "Negative"}],'
                               '"Staff":[{"text": "The receptionist was polite and friendly.","label": "Positive"}],'
                               '"Location1":[{"text": "close to the airport, which made traveling easy.","label": "Positive"}],'
                               '"Location2":[{"text": "there was a lot of street noise outside the window.","label": "Negative"}],'
                               '"Food1":[{"text": "The breakfast buffet was delicious.","label": "Positive"}],'
                               '"Food2":[{"text": "the coffee was terrible.","label": "Negative"}],'
                               '"Price":[{"text": "The price was reasonable for the quality.","label": "Positive"}],'
                               '"Facility1":[{"text": "The hotel was new.","label": "Positive"}],'
                               '"Facility2":[{"text": "The hotel lobby was welcoming and spacious.","label": "Positive"}],'
                               '"Facility3":[{"text": "The building was charming with historical architecture.","label": "Positive"}],'
                               '"Check-in":[{"text": "check-in took longer than expected.","label": "Negative"}],'
                               '"Check-out":[{"text": null,"label": null}],'
                               '"Taxi-issue":[{"text": null,"label": null}],'
                               '"Booking-issue":[{"text": null,"label": null}],'
                               '"Off":[{"text": "Location. Staff.","label": null}]}]}'
        },

        # Example 4
        {"role": "user", "content": "location, service, overall was good, Sure worth it to come back again"},
        {"role": "assistant", "content": '{"Topics":[{"Room":[{"text": null,"label": null}],'
                                '"Staff":[{"text": null,"label": null}],'
                                '"Location":[{"text": null,"label": null}],'
                                '"Food":[{"text": null,"label": null}],'
                                '"Price":[{"text": null,"label": null}],'
                                '"Facility":[{"text": null,"label": null}],'
                                '"Check-in":[{"text": null,"label": null}],'
                                '"Check-out":[{"text": null,"label": null}],'
                                '"Taxi-issue":[{"text": null,"label": null}],'
                                '"Booking-issue":[{"text": null,"label": null}],'
                                '"Off":[{"text": "location, service, overall was good, Sure worth it to come back again","label": "Positive"}]}]}'
        },

        # Example 5
        {"role": "user", "content": "The apartment was new. The breakfast was amazing and the price was quite reasonable. Overall, we definitely planning to return again soon!"},
        {"role": "assistant", "content": '{"Topics":[{"Room":[{"text": null,"label": null}],'
                                '"Staff":[{"text": null,"label": null}],'
                                '"Location":[{"text": null,"label": null}],'
                                '"Food":[{"text": "The breakfast was amazing and the price was quite reasonable.","label": "Positive"}],'
                                '"Price":[{"text": null,"label": null}],'
                                '"Facility":[{"text": "The apartment was new.","label": "Positive"}],'
                                '"Check-in":[{"text": null,"label": null}],'
                                '"Check-out":[{"text": null,"label": null}],'
                                '"Taxi-issue":[{"text": null,"label": null}],'
                                '"Booking-issue":[{"text": null,"label": null}],'
                                '"Off":[{"text": "Overall, we definitely planning to return again soon!","label": "Positive"}]}]}'
        },
    
        # Real input
        {"role": "user", "content": review_text}
    ]


    full_prompt = build_full_prompt(messages)

    response = model.generate_content(
        [full_prompt],
        generation_config={
            "temperature": 0,
            "top_p": 0.05
        }
    )

    return response.text, full_prompt

# ----------- Run for ALL rows -------------
for run_num in range(1, 4):  # 1 to 3
    final_results = []

    for idx, row in df_combined.iterrows():
        review_text = row['Review']
        review_id = row['ID']
        
        print(f"[Run {run_num}] Processing review ID {review_id}...")

        try:
            response_content, full_prompt = send_prompt(review_text)
            print(f"[Run {run_num}] Raw response for ID {review_id}:\n{response_content}\n")
            
            review_results = parse_response(response_content, review_id, full_prompt)
            final_results.extend(review_results)

        except Exception as e:
            print(f"[Run {run_num}] Error processing ID {review_id}: {e}")

    # Save results
    output_df = pd.DataFrame(final_results)
    output_csv_path = f'ABA_dataset_2_gemini_2.5_pro_5_shot_{run_num}.csv'
    output_df.to_csv(output_csv_path, index=False)
    print(f" Done! Results saved to {output_csv_path}")
