# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

output_file = '/Users/nonny/Documents/GitHub/benchmarking-aba-dataset/Dataset 1/Prompt Version 1/Result-4-shot/Temp 1, top_p 1/output_formatted_reviews_gpt4o_4_v4.csv'
answer_key_file = 'ABA Dataset - Label Topic (For Tasks 1 & 2).xlsx'

df_output = pd.read_csv(output_file)
df_answer_key = pd.read_excel(answer_key_file)

# %%
# Clean answer key
df_answer_cleaned = df_answer_key[['Unnamed: 0', 'Topic', 'Selected Content', 'Pos/Neg']].rename(columns={
    'Unnamed: 0': 'ID',
    'Topic': 'Topics',
    'Selected Content': 'Text_answer',
    'Pos/Neg': 'NegPos_answer'
})

df_answer_cleaned.head(30)
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1  Location         close to the airport, to very clean beach.
# 1    1     Staff  Staff is extremely helpful and easy to communi...
# 2    1      Food  Tasty food on the first floor, comfortable res...
# 3    2     Staff               The staff was very nice and helpful!
# 4    2      Room  The room was very clean, well decorated and mo...
# 5    2      Food  Also, the breakfast was amazing, fresh and han...
# 6    3  Location  the location is great and near the airport. bu...
# 7    4     Staff                                        Great stuff
# 8    4     Price                                Great Quality/price
# 9    4      Room                                              Clean
# 10   5      Room        Clean and modern with very comfortable beds
# 11   5  Location  in a very convenient location.  An easy stroll...
# 12   6      Room  The room was exceptionally clean with a really...
# 13   8  Location                                      nice location
# 14   8     Staff                                    lovely personal
# 15   9     Staff  very helpful host showed us how nearby bus tak...
# 16  10      Room                  Great modern room comfortable bed
# 17  10  Location                                     quiet location
# 18  11     Staff  The staff here are amazing beyond expectations...
# 19  11      Food  Oh yeah the food is great to and very reasonab...
# 20  11      Room  The rooms are spacious and clean great to stay...
# 21  11  Location  The bus stop which goes to and from the airpor...
# 22  12     Staff  The staff were exceptional. So helpful and fri...
# 23  12      Food    The breakfast was lovely with room service too.
# 24  12      Room                        Very clean and comfortable.
# 25  13      Room  The rooms are lovely and new, very clean and c...
# 26  13  Location  Short drive to the airport and very well locat...
# 27  13     Staff  The staff are so welcoming, we felt like stayi...
# 28  14  Location  We wanted a hotel for a night that is close to...
# 29  14     Staff     The receptionist didn't speak English properly
#
#    NegPos_answer
# 0       Positive
# 1       Positive
# 2       Positive
# 3       Positive
# 4       Positive
# 5       Positive
# 6       Positive
# 7       Positive
# 8       Positive
# 9       Positive
# 10      Positive
# 11      Positive
# 12      Positive
# 13      Positive
# 14      Positive
# 15      Positive
# 16      Positive
# 17      Positive
# 18      Positive
# 19      Positive
# 20      Positive
# 21      Positive
# 22      Positive
# 23      Positive
# 24      Positive
# 25      Positive
# 26      Positive
# 27      Positive
# 28      Positive
# 29      Negative

# %%
# Clean Output
def clean_topic(topic):
    return re.sub(r'\d+$', '', str(topic))

df_output['Cleaned_Topics'] = df_output['Topics'].apply(clean_topic)

df_output_cleaned = df_output[['ID', 'Cleaned_Topics', 'Text', 'NegPos']].copy()
df_output_cleaned.rename(columns={'Cleaned_Topics': 'Topics'}, inplace=True)
df_output_cleaned = df_output_cleaned[~(df_output_cleaned['Text'].isna() & df_output_cleaned['NegPos'].isna())]

# df_output_cleaned.head(30)

df_output_merged = df_output_cleaned.groupby(['ID', 'Topics', 'NegPos']).agg({
    'Text': lambda x: ', '.join(x.dropna().astype(str).str.strip())
}).reset_index()


# df_output_merged.head(30)
df_output_merged[df_output_merged['ID'] == 22]
# Out:
#     ID    Topics    NegPos                                               Text
# 61  22  Facility  Positive                       The restaurant area is nice.
# 62  22      Food  Negative  Ordered pizza one night and was not great, too...
# 63  22      Food  Positive                     I'm sure other food is better.
# 64  22      Room  Negative  might have needed another set of drawers if th...
# 65  22      Room  Positive  Room was perfect, looked new, clean shiny tile...
# 66  22     Staff  Positive                      The staff very accommodating.

# %%
# Merge on ID and Topics
# Use 'ID', 'Topics', and 'NegPos' as the keys to align the data
# 'NegPos' is renamed to 'NegPos_answer' in df_answer_cleaned before the merge, so we match on that
# Use an OUTER JOIN to capture all possible cases:
# - Matching (ID, Topics, Sentiment) pairs
# - Missing predictions (False Negatives)
# - Extra predictions (False Positives)
df_compare = pd.merge(
    df_answer_cleaned,
    df_output_merged,
    left_on=['ID', 'Topics', 'NegPos_answer'],
    right_on=['ID', 'Topics', 'NegPos'],
    how='outer',
    suffixes=('_answer', '_output')
)

df_compare.rename(columns={
    'Text': 'Text_output',
    'NegPos': 'NegPos_output'
}, inplace=True)

# Filter out rows where BOTH 'Text_answer' and 'Text_output' are missing or empty
df_compare = df_compare[~(
    (df_compare['Text_answer'].isna() | df_compare['Text_answer'].str.strip().eq('')) &
    (df_compare['Text_output'].isna() | df_compare['Text_output'].str.strip().eq(''))
)]

# Remove topics labeled as 'Off'
# df_compare = df_compare[df_compare['Topics'] != 'Off']
df_compare.head(30)
# df_compare[df_compare['ID'] == 22]
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1      Food  Tasty food on the first floor, comfortable res...
# 1    1  Location         close to the airport, to very clean beach.
# 2    1      Room                                                NaN
# 3    1     Staff  Staff is extremely helpful and easy to communi...
# 4    2  Facility                                                NaN
# 5    2      Food  Also, the breakfast was amazing, fresh and han...
# 6    2      Room                                                NaN
# 7    2      Room  The room was very clean, well decorated and mo...
# 8    2     Staff               The staff was very nice and helpful!
# 9    3  Location  the location is great and near the airport. bu...
# 10   4     Price                                Great Quality/price
# 11   4      Room                                              Clean
# 12   4     Staff                                        Great stuff
# 13   5  Location  in a very convenient location.  An easy stroll...
# 14   5      Room        Clean and modern with very comfortable beds
# 15   6      Room  The room was exceptionally clean with a really...
# 16   8  Location                                      nice location
# 17   8      Room                                                NaN
# 18   8     Staff                                    lovely personal
# 19   9      Food                                                NaN
# 20   9  Location                                                NaN
# 21   9     Price                                                NaN
# 22   9     Staff  very helpful host showed us how nearby bus tak...
# 23  10  Location                                     quiet location
# 24  10      Room                  Great modern room comfortable bed
# 25  11      Food  Oh yeah the food is great to and very reasonab...
# 26  11  Location  The bus stop which goes to and from the airpor...
# 27  11     Price                                                NaN
# 28  11      Room  The rooms are spacious and clean great to stay...
# 29  11     Staff  The staff here are amazing beyond expectations...
#
#    NegPos_answer NegPos_output  \
# 0       Positive      Positive
# 1       Positive      Positive
# 2            NaN      Positive
# 3       Positive      Positive
# 4            NaN      Positive
# 5       Positive      Positive
# 6            NaN      Negative
# 7       Positive      Positive
# 8       Positive      Positive
# 9       Positive      Positive
# 10      Positive      Positive
# 11      Positive      Positive
# 12      Positive      Positive
# 13      Positive      Positive
# 14      Positive      Positive
# 15      Positive      Positive
# 16      Positive      Positive
# 17           NaN      Positive
# 18      Positive      Positive
# 19           NaN      Negative
# 20           NaN      Positive
# 21           NaN      Positive
# 22      Positive      Positive
# 23      Positive      Positive
# 24      Positive      Positive
# 25      Positive      Positive
# 26      Positive      Positive
# 27           NaN      Positive
# 28      Positive      Positive
# 29      Positive      Positive
#
#                                           Text_output
# 0   Tasty food on the first floor, comfortable res...
# 1          close to the airport, to very clean beach.
# 2                         New, comfortable apartments
# 3   Staff is extremely helpful and easy to communi...
# 4   I like hotels with a family atmosphere, cozy a...
# 5   the breakfast was amazing, fresh and handmade!...
# 6                                   although not big.
# 7   The room was very clean, well decorated and mo...
# 8   The staff was very nice and helpful. all staff...
# 9   the location is great and near the airport. bu...
# 10                                Great Quality/price
# 11                                              Clean
# 12                                        Great staff
# 13  in a very convenient location. An easy stroll ...
# 14       Clean and modern with very comfortable beds.
# 15  The room was exceptionally clean with a really...
# 16                                      nice location
# 17                                          renovated
# 18                                    lovely personal
# 19  couldn't eat breakfast due to dietary restrict...
# 20  very helpful host showed us how nearby bus tak...
# 21                           no need for 21 euro taxi
# 22  very helpful host showed us how nearby bus tak...
# 23                                     quiet location
# 24                 Great modern room, comfortable bed
# 25      The food is great and very reasonable prices.
# 26  The bus stop which goes to and from the airpor...
# 27                             very reasonable prices
# 28  The rooms are spacious and clean great to stay...
# 29  The staff here are amazing beyond expectations...

# %%
# Combine all text data from both the answer key and model output into a single list 
# - Use .fillna('') to replace NaN with empty strings to avoid errors
all_texts = df_compare['Text_answer'].fillna('').tolist() + df_compare['Text_output'].fillna('').tolist()

# Initialize the TF-IDF Vectorizer
# - lowercase=True: converts all text to lowercase for normalization
# - token_pattern=r"(?u)\b\w+\b": matches any single word (includes single letters and numbers), so it's more general than the default
vectorizer = TfidfVectorizer(lowercase=True, token_pattern=r"(?u)\b\w+\b")

vectorizer.fit(all_texts)
# Out:
# TfidfVectorizer(token_pattern='(?u)\\b\\w+\\b')

# %%
# Define a function to compute cosine similarity between two text strings using TF-IDF
def compute_cosine(text1, text2, vectorizer):
    # Case 1: If either text is NaN, return 0 similarity
    if pd.isna(text1) or pd.isna(text2):
        return 0.0

    # Strip leading/trailing spaces to avoid issues with empty strings
    text1 = str(text1).strip()
    text2 = str(text2).strip()
    # Case 2: If either text is empty after stripping, return 0 similarity
    if text1 == '' or text2 == '':
        return 0.0

    # Transform both texts into TF-IDF vectors using the pre-fitted vectorizer
    tfidf = vectorizer.transform([text1, text2])
    return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]

df_compare['Cosine_Similarity'] = df_compare.apply(
    lambda row: compute_cosine(row['Text_answer'], row['Text_output'], vectorizer),
    axis=1
)

df_compare[['ID', 'Topics', 'Text_answer', 'Text_output', 'Cosine_Similarity']].head(30)
# Out:
#     ID    Topics                                        Text_answer  \
# 0    1      Food  Tasty food on the first floor, comfortable res...
# 1    1  Location         close to the airport, to very clean beach.
# 2    1      Room                                                NaN
# 3    1     Staff  Staff is extremely helpful and easy to communi...
# 4    2  Facility                                                NaN
# 5    2      Food  Also, the breakfast was amazing, fresh and han...
# 6    2      Room                                                NaN
# 7    2      Room  The room was very clean, well decorated and mo...
# 8    2     Staff               The staff was very nice and helpful!
# 9    3  Location  the location is great and near the airport. bu...
# 10   4     Price                                Great Quality/price
# 11   4      Room                                              Clean
# 12   4     Staff                                        Great stuff
# 13   5  Location  in a very convenient location.  An easy stroll...
# 14   5      Room        Clean and modern with very comfortable beds
# 15   6      Room  The room was exceptionally clean with a really...
# 16   8  Location                                      nice location
# 17   8      Room                                                NaN
# 18   8     Staff                                    lovely personal
# 19   9      Food                                                NaN
# 20   9  Location                                                NaN
# 21   9     Price                                                NaN
# 22   9     Staff  very helpful host showed us how nearby bus tak...
# 23  10  Location                                     quiet location
# 24  10      Room                  Great modern room comfortable bed
# 25  11      Food  Oh yeah the food is great to and very reasonab...
# 26  11  Location  The bus stop which goes to and from the airpor...
# 27  11     Price                                                NaN
# 28  11      Room  The rooms are spacious and clean great to stay...
# 29  11     Staff  The staff here are amazing beyond expectations...
#
#                                           Text_output  Cosine_Similarity
# 0   Tasty food on the first floor, comfortable res...           1.000000
# 1          close to the airport, to very clean beach.           1.000000
# 2                         New, comfortable apartments           0.000000
# 3   Staff is extremely helpful and easy to communi...           1.000000
# 4   I like hotels with a family atmosphere, cozy a...           0.000000
# 5   the breakfast was amazing, fresh and handmade!...           0.802906
# 6                                   although not big.           0.000000
# 7   The room was very clean, well decorated and mo...           0.772769
# 8   The staff was very nice and helpful. all staff...           0.861318
# 9   the location is great and near the airport. bu...           1.000000
# 10                                Great Quality/price           1.000000
# 11                                              Clean           1.000000
# 12                                        Great staff           0.392419
# 13  in a very convenient location. An easy stroll ...           1.000000
# 14       Clean and modern with very comfortable beds.           1.000000
# 15  The room was exceptionally clean with a really...           1.000000
# 16                                      nice location           1.000000
# 17                                          renovated           0.000000
# 18                                    lovely personal           1.000000
# 19  couldn't eat breakfast due to dietary restrict...           0.000000
# 20  very helpful host showed us how nearby bus tak...           0.000000
# 21                           no need for 21 euro taxi           0.000000
# 22  very helpful host showed us how nearby bus tak...           0.738151
# 23                                     quiet location           1.000000
# 24                 Great modern room, comfortable bed           1.000000
# 25      The food is great and very reasonable prices.           0.751305
# 26  The bus stop which goes to and from the airpor...           1.000000
# 27                             very reasonable prices           0.000000
# 28  The rooms are spacious and clean great to stay...           1.000000
# 29  The staff here are amazing beyond expectations...           0.992437

# %%
def isCorrect(row):
    # Case 1: If either the human-labeled text or the model output text is missing, mark as incorrect
    if pd.isna(row['Text_answer']) or pd.isna(row['Text_output']):
        return False
    # Case 2: If cosine similarity is missing (NaN), mark as incorrect
    if pd.isna(row['Cosine_Similarity']):
        return False
     # Case 3: If the cosine similarity is greater than or equal to 0.7, consider it correct
    return row['Cosine_Similarity'] >= 0.7

df_compare['IsCorrect'] = df_compare.apply(isCorrect, axis=1)

# Optional:
# Display the first 40 rows to review the following columns:
# - ID: Data point ID
# - Topics: Topic label
# - NegPos_answer: Human-labeled sentiment
# - NegPos_output: Model-predicted sentiment
# - Text_answer: Human-labeled text span
# - Text_output: Model-predicted text span
# - Cosine_Similarity: Similarity score between the texts
# - IsCorrect: Boolean flag indicating whether the extraction is correct based on the similarity threshold
df_compare[['ID', 'Topics', 'NegPos_answer', 'NegPos_output', 'Text_answer', 'Text_output', 'Cosine_Similarity', 'IsCorrect']].head(40)
# Out:
#     ID    Topics NegPos_answer NegPos_output  \
# 0    1      Food      Positive      Positive
# 1    1  Location      Positive      Positive
# 2    1      Room           NaN      Positive
# 3    1     Staff      Positive      Positive
# 4    2  Facility           NaN      Positive
# 5    2      Food      Positive      Positive
# 6    2      Room           NaN      Negative
# 7    2      Room      Positive      Positive
# 8    2     Staff      Positive      Positive
# 9    3  Location      Positive      Positive
# 10   4     Price      Positive      Positive
# 11   4      Room      Positive      Positive
# 12   4     Staff      Positive      Positive
# 13   5  Location      Positive      Positive
# 14   5      Room      Positive      Positive
# 15   6      Room      Positive      Positive
# 16   8  Location      Positive      Positive
# 17   8      Room           NaN      Positive
# 18   8     Staff      Positive      Positive
# 19   9      Food           NaN      Negative
# 20   9  Location           NaN      Positive
# 21   9     Price           NaN      Positive
# 22   9     Staff      Positive      Positive
# 23  10  Location      Positive      Positive
# 24  10      Room      Positive      Positive
# 25  11      Food      Positive      Positive
# 26  11  Location      Positive      Positive
# 27  11     Price           NaN      Positive
# 28  11      Room      Positive      Positive
# 29  11     Staff      Positive      Positive
# 30  12      Food      Positive      Positive
# 31  12      Room      Positive      Positive
# 32  12     Staff      Positive      Positive
# 33  13  Location      Positive      Positive
# 34  13      Room      Positive      Positive
# 35  13     Staff      Positive      Positive
# 36  14  Facility           NaN      Negative
# 37  14  Location           NaN      Negative
# 38  14  Location      Positive      Positive
# 39  14      Room      Negative           NaN
#
#                                           Text_answer  \
# 0   Tasty food on the first floor, comfortable res...
# 1          close to the airport, to very clean beach.
# 2                                                 NaN
# 3   Staff is extremely helpful and easy to communi...
# 4                                                 NaN
# 5   Also, the breakfast was amazing, fresh and han...
# 6                                                 NaN
# 7   The room was very clean, well decorated and mo...
# 8                The staff was very nice and helpful!
# 9   the location is great and near the airport. bu...
# 10                                Great Quality/price
# 11                                              Clean
# 12                                        Great stuff
# 13  in a very convenient location.  An easy stroll...
# 14        Clean and modern with very comfortable beds
# 15  The room was exceptionally clean with a really...
# 16                                      nice location
# 17                                                NaN
# 18                                    lovely personal
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  very helpful host showed us how nearby bus tak...
# 23                                     quiet location
# 24                  Great modern room comfortable bed
# 25  Oh yeah the food is great to and very reasonab...
# 26  The bus stop which goes to and from the airpor...
# 27                                                NaN
# 28  The rooms are spacious and clean great to stay...
# 29  The staff here are amazing beyond expectations...
# 30    The breakfast was lovely with room service too.
# 31                        Very clean and comfortable.
# 32  The staff were exceptional. So helpful and fri...
# 33  Short drive to the airport and very well locat...
# 34  The rooms are lovely and new, very clean and c...
# 35  The staff are so welcoming, we felt like stayi...
# 36                                                NaN
# 37                                                NaN
# 38  We wanted a hotel for a night that is close to...
# 39  You can hear the airplanes coming and leaving ...
#
#                                           Text_output  Cosine_Similarity  \
# 0   Tasty food on the first floor, comfortable res...           1.000000
# 1          close to the airport, to very clean beach.           1.000000
# 2                         New, comfortable apartments           0.000000
# 3   Staff is extremely helpful and easy to communi...           1.000000
# 4   I like hotels with a family atmosphere, cozy a...           0.000000
# 5   the breakfast was amazing, fresh and handmade!...           0.802906
# 6                                   although not big.           0.000000
# 7   The room was very clean, well decorated and mo...           0.772769
# 8   The staff was very nice and helpful. all staff...           0.861318
# 9   the location is great and near the airport. bu...           1.000000
# 10                                Great Quality/price           1.000000
# 11                                              Clean           1.000000
# 12                                        Great staff           0.392419
# 13  in a very convenient location. An easy stroll ...           1.000000
# 14       Clean and modern with very comfortable beds.           1.000000
# 15  The room was exceptionally clean with a really...           1.000000
# 16                                      nice location           1.000000
# 17                                          renovated           0.000000
# 18                                    lovely personal           1.000000
# 19  couldn't eat breakfast due to dietary restrict...           0.000000
# 20  very helpful host showed us how nearby bus tak...           0.000000
# 21                           no need for 21 euro taxi           0.000000
# 22  very helpful host showed us how nearby bus tak...           0.738151
# 23                                     quiet location           1.000000
# 24                 Great modern room, comfortable bed           1.000000
# 25      The food is great and very reasonable prices.           0.751305
# 26  The bus stop which goes to and from the airpor...           1.000000
# 27                             very reasonable prices           0.000000
# 28  The rooms are spacious and clean great to stay...           1.000000
# 29  The staff here are amazing beyond expectations...           0.992437
# 30    The breakfast was lovely with room service too.           1.000000
# 31                        Very clean and comfortable.           1.000000
# 32  The staff were exceptional. So helpful and fri...           1.000000
# 33  Short drive to the airport and very well locat...           1.000000
# 34  The rooms are lovely and new, very clean and c...           1.000000
# 35  The staff are so welcoming, we felt like stayi...           1.000000
# 36  you have a feeling that people are living in t...           0.000000
# 37  You can hear the airplanes coming and leaving ...           0.000000
# 38  close to the airport, There are some restauran...           0.714727
# 39                                                NaN           0.000000
#
#     IsCorrect
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
# 5        True
# 6       False
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13       True
# 14       True
# 15       True
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27      False
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36      False
# 37      False
# 38       True
# 39      False

# %%
# df_compare.to_csv('cosine_7_shot.csv', index=False)

# print("CSV saved successfully")

# %%
eval_list = []

for id_val in sorted(df_compare['ID'].unique()):
    df_id = df_compare[df_compare['ID'] == id_val]

    num_preds = df_id['Text_output'].notna().sum()  # Model output per ID
    num_ans = df_id['Text_answer'].notna().sum()    # Ground truth per ID
    num_correct = df_id['IsCorrect'].sum()           # Correct cosine matches

    # Precision = Correct Predictions / Total Predictions
    precision = num_correct / num_preds if num_preds > 0 else 0
    # Recall = Correct Predictions / Total Answers
    recall = num_correct / num_ans if num_ans > 0 else 0
    
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    # Append results as a dictionary into eval_list
    eval_list.append({
        'ID': id_val,               # Current ID
        'pre_nom': num_correct,     # Numerator for Precision (True Positives)
        'pre_denom': num_preds,     # Denominator for Precision (Model outputs)
        'Precision': precision,     
        're_nom': num_correct,      # Numerator for Recall (True Positives)
        're_denom': num_ans,        # Denominator for Recall (Human annotations)
        'Recall': recall,
        'F1': f1
    })


eval_df = pd.DataFrame(eval_list).sort_values('ID').reset_index(drop=True)


eval_df.head(30)
# Out:
#     ID  pre_nom  pre_denom  Precision  re_nom  re_denom    Recall        F1
# 0    1        3          4   0.750000       3         3  1.000000  0.857143
# 1    2        3          5   0.600000       3         3  1.000000  0.750000
# 2    3        1          1   1.000000       1         1  1.000000  1.000000
# 3    4        2          3   0.666667       2         3  0.666667  0.666667
# 4    5        2          2   1.000000       2         2  1.000000  1.000000
# 5    6        1          1   1.000000       1         1  1.000000  1.000000
# 6    8        2          3   0.666667       2         2  1.000000  0.800000
# 7    9        1          4   0.250000       1         1  1.000000  0.400000
# 8   10        2          2   1.000000       2         2  1.000000  1.000000
# 9   11        4          5   0.800000       4         4  1.000000  0.888889
# 10  12        3          3   1.000000       3         3  1.000000  1.000000
# 11  13        3          3   1.000000       3         3  1.000000  1.000000
# 12  14        2          4   0.500000       2         3  0.666667  0.571429
# 13  15        1          3   0.333333       1         1  1.000000  0.500000
# 14  16        2          2   1.000000       2         2  1.000000  1.000000
# 15  17        2          2   1.000000       2         2  1.000000  1.000000
# 16  18        3          7   0.428571       3         3  1.000000  0.600000
# 17  19        1          1   1.000000       1         1  1.000000  1.000000
# 18  20        2          3   0.666667       2         3  0.666667  0.666667
# 19  21        2          3   0.666667       2         3  0.666667  0.666667
# 20  22        3          6   0.500000       3         4  0.750000  0.600000
# 21  23        1          1   1.000000       1         1  1.000000  1.000000
# 22  24        1          1   1.000000       1         1  1.000000  1.000000
# 23  25        1          1   1.000000       1         1  1.000000  1.000000
# 24  26        4          6   0.666667       4         4  1.000000  0.800000
# 25  27        3          3   1.000000       3         3  1.000000  1.000000
# 26  28        2          2   1.000000       2         2  1.000000  1.000000
# 27  29        2          3   0.666667       2         2  1.000000  0.800000
# 28  30        3          3   1.000000       3         3  1.000000  1.000000
# 29  31        4          4   1.000000       4         4  1.000000  1.000000

# %%
# Save to CSV
# eval_df.to_csv("evaluation_result_7_shot.csv", index=False)

print("Evaluation results saved to .csv")
# Out:
# Evaluation results saved to .csv

# %%
macro_precision = eval_df['Precision'].mean()
macro_recall = eval_df['Recall'].mean()
macro_f1 = eval_df['F1'].mean() 

print(f"Macro Precision: {macro_precision:.4f}")
print(f"Macro Recall: {macro_recall:.4f}")
print(f"Macro F1-score: {macro_f1:.4f}")
# Out:
# Macro Precision: 0.5900
# Macro Recall: 0.8052
# Macro F1-score: 0.6468

# %%
# Total correct predictions
total_correct = df_compare['IsCorrect'].sum()
total_answers = df_compare['Text_answer'].notna().sum()
accuracy = total_correct / total_answers if total_answers > 0 else 0

print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8268
